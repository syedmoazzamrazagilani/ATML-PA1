# %%
# !git clone https://github.com/syedmoazzamrazagilani/ATML-PA1.git
# Out:
# Cloning into 'ATML-PA1'...
# remote: Enumerating objects: 453, done.
# remote: Counting objects: 100% (453/453), done.
# remote: Compressing objects: 100% (412/412), done.
# remote: Total 453 (delta 183), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (453/453), 173.85 KiB | 5.99 MiB/s, done.
# Resolving deltas: 100% (183/183), done.

# %%
# %cd ATML-PA1
# Out:
# /kaggle/working/ATML-PA1

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (0.25.0+cu128)
# Requirement already satisfied: open-clip-torch>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.3.0)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: timm>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.0.26)
# Requirement already satisfied: pillow>=9.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: umap-learn>=0.5.3 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.5.12)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (2025.11.3)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (6.3.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.2->umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.24.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.1.2)

# %%
# !python -m task1.data.make_subset
# Out:
# 100%|██████████████████████████████████████| 2.64G/2.64G [03:23<00:00, 12.9MB/s]
# Splits saved to /kaggle/working/ATML-PA1/task1/data_cache/stl10_splits_seed6304.json
# Train samples: 4000, Val samples: 1000, Test subset: 500

# %%
# !git pull
# Out:
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 45 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (45/45), 24.85 KiB | 848.00 KiB/s, done.
# From https://github.com/syedmoazzamrazagilani/ATML-PA1
#    8ac87f6..657c250  main       -> origin/main
# Updating 8ac87f6..657c250
# Fast-forward
#  task1/analysis/evaluate_bias.py               | 281 ++++++++-----------
#  task1/analysis/evaluate_color_bias.py         | 101 +++++++
#  task1/analysis/evaluate_cue_conflicts.py      | 161 +++++++++++
#  task1/analysis/evaluate_patch_shuffle.py      |  82 ++++++
#  task1/analysis/evaluate_translation.py        | 129 +++++++++
#  task1/analysis/plot_translation.py            | 125 +++++++--
#  task1/analysis/run_representation_analysis.py | 390 ++++++++++++++++----------
#  task1/models/train_heads.py                   | 179 ++++++++++++
#  task1/scripts/run_task1.py                    | 204 ++++----------
#  9 files changed, 1168 insertions(+), 484 deletions(-)
#  create mode 100644 task1/analysis/evaluate_color_bias.py
#  create mode 100644 task1/analysis/evaluate_cue_conflicts.py
#  create mode 100644 task1/analysis/evaluate_patch_shuffle.py
#  create mode 100644 task1/analysis/evaluate_translation.py
#  create mode 100644 task1/models/train_heads.py

# %%
# !python -m task1.models.train_heads
# Out:
# ==================================================
#   Training head for: resnet50
# ==================================================
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|███████████████████████████████████████| 97.8M/97.8M [00:00<00:00, 161MB/s]
#   Epoch 01 | val_acc=0.9390 | best=0.9390 | patience=0/5
#   Epoch 02 | val_acc=0.9510 | best=0.9510 | patience=0/5
#   Epoch 03 | val_acc=0.9570 | best=0.9570 | patience=0/5
#   Epoch 04 | val_acc=0.9620 | best=0.9620 | patience=0/5
#   Epoch 05 | val_acc=0.9630 | best=0.9630 | patience=0/5
#   Epoch 06 | val_acc=0.9600 | best=0.9630 | patience=1/5
#   Epoch 07 | val_acc=0.9670 | best=0.9670 | patience=0/5
#   Epoch 08 | val_acc=0.9670 | best=0.9670 | patience=1/5
#   Epoch 09 | val_acc=0.9620 | best=0.9670 | patience=2/5
#   Epoch 10 | val_acc=0.9640 | best=0.9670 | patience=3/5
#   Epoch 11 | val_acc=0.9670 | best=0.9670 | patience=4/5
#   Epoch 12 | val_acc=0.9660 | best=0.9670 | patience=5/5
#   Early stopping at epoch 12.
#   Saved head to /kaggle/working/ATML-PA1/task1/results/heads/resnet50_head.pt
#   Clean test  ->  acc=0.9540  f1=0.9540  conf=0.9087
#
# ==================================================
#   Training head for: vit_b_16
# ==================================================
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|█████████████████████████████████████████| 330M/330M [00:01<00:00, 213MB/s]
#   Epoch 01 | val_acc=0.9750 | best=0.9750 | patience=0/5
#   Epoch 02 | val_acc=0.9740 | best=0.9750 | patience=1/5
#   Epoch 03 | val_acc=0.9750 | best=0.9750 | patience=2/5
#   Epoch 04 | val_acc=0.9790 | best=0.9790 | patience=0/5
#   Epoch 05 | val_acc=0.9810 | best=0.9810 | patience=0/5
#   Epoch 06 | val_acc=0.9830 | best=0.9830 | patience=0/5
#   Epoch 07 | val_acc=0.9830 | best=0.9830 | patience=1/5
#   Epoch 08 | val_acc=0.9830 | best=0.9830 | patience=2/5
#   Epoch 09 | val_acc=0.9830 | best=0.9830 | patience=3/5
#   Epoch 10 | val_acc=0.9830 | best=0.9830 | patience=4/5
#   Epoch 11 | val_acc=0.9830 | best=0.9830 | patience=5/5
#   Early stopping at epoch 11.
#   Saved head to /kaggle/working/ATML-PA1/task1/results/heads/vit_b_16_head.pt
#   Clean test  ->  acc=0.9740  f1=0.9741  conf=0.9618
#
# ==================================================
#   Training head for: clip_vit_b_32
# ==================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# open_clip_model.safetensors: 100%|███████████| 605M/605M [00:11<00:00, 53.3MB/s]
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   Epoch 01 | val_acc=0.9690 | best=0.9690 | patience=0/5
#   Epoch 02 | val_acc=0.9700 | best=0.9700 | patience=0/5
#   Epoch 03 | val_acc=0.9750 | best=0.9750 | patience=0/5
#   Epoch 04 | val_acc=0.9770 | best=0.9770 | patience=0/5
#   Epoch 05 | val_acc=0.9790 | best=0.9790 | patience=0/5
#   Epoch 06 | val_acc=0.9790 | best=0.9790 | patience=1/5
#   Epoch 07 | val_acc=0.9810 | best=0.9810 | patience=0/5
#   Epoch 08 | val_acc=0.9790 | best=0.9810 | patience=1/5
#   Epoch 09 | val_acc=0.9800 | best=0.9810 | patience=2/5
#   Epoch 10 | val_acc=0.9790 | best=0.9810 | patience=3/5
#   Epoch 11 | val_acc=0.9790 | best=0.9810 | patience=4/5
#   Epoch 12 | val_acc=0.9790 | best=0.9810 | patience=5/5
#   Early stopping at epoch 12.
#   Saved head to /kaggle/working/ATML-PA1/task1/results/heads/clip_vit_b_32_head.pt
#   Clean test  ->  acc=0.9700  f1=0.9698  conf=0.4362
#   Running CLIP zero-shot …
#   CLIP ZS     ->  acc=0.9320  f1=0.9305  conf=0.9211
#
# Saved clean baseline to /kaggle/working/ATML-PA1/task1/results/clean_baseline.json

# %%
# !python -m task1.data.make_cue_conflicts
# Out:
# Loading VGG19 for Style Transfer...
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|█████████████████████████████████████████| 548M/548M [00:03<00:00, 176MB/s]
# Generated 2/200 conflicts
# Generated 4/200 conflicts
# Generated 6/200 conflicts
# Generated 8/200 conflicts
# Generated 10/200 conflicts
# Generated 12/200 conflicts
# Generated 14/200 conflicts
# Generated 16/200 conflicts
# Generated 18/200 conflicts
# Generated 20/200 conflicts
# Generated 22/200 conflicts
# Generated 24/200 conflicts
# Generated 26/200 conflicts
# Generated 28/200 conflicts
# Generated 30/200 conflicts
# Generated 32/200 conflicts
# Generated 34/200 conflicts
# Generated 36/200 conflicts
# Generated 38/200 conflicts
# Generated 40/200 conflicts
# Generated 42/200 conflicts
# Generated 44/200 conflicts
# Generated 46/200 conflicts
# Generated 48/200 conflicts
# Generated 50/200 conflicts
# Generated 52/200 conflicts
# Generated 54/200 conflicts
# Generated 56/200 conflicts
# Generated 58/200 conflicts
# Generated 60/200 conflicts
# Generated 62/200 conflicts
# Generated 64/200 conflicts
# Generated 66/200 conflicts
# Generated 68/200 conflicts
# Generated 70/200 conflicts
# Generated 72/200 conflicts
# Generated 74/200 conflicts
# Generated 76/200 conflicts
# Generated 78/200 conflicts
# Generated 80/200 conflicts
# Generated 82/200 conflicts
# Generated 84/200 conflicts
# Generated 86/200 conflicts
# Generated 88/200 conflicts
# Generated 90/200 conflicts
# Generated 92/200 conflicts
# Generated 94/200 conflicts
# Generated 96/200 conflicts
# Generated 98/200 conflicts
# Generated 100/200 conflicts
# Generated 102/200 conflicts
# Generated 104/200 conflicts
# Generated 106/200 conflicts
# Generated 108/200 conflicts
# Generated 110/200 conflicts
# Generated 112/200 conflicts
# Generated 114/200 conflicts
# Generated 116/200 conflicts
# Generated 118/200 conflicts
# Generated 120/200 conflicts
# Generated 122/200 conflicts
# Generated 124/200 conflicts
# Generated 126/200 conflicts
# Generated 128/200 conflicts
# Generated 130/200 conflicts
# Generated 132/200 conflicts
# Generated 134/200 conflicts
# Generated 136/200 conflicts
# Generated 138/200 conflicts
# Generated 140/200 conflicts
# Generated 142/200 conflicts
# Generated 144/200 conflicts
# Generated 146/200 conflicts
# Generated 148/200 conflicts
# Generated 150/200 conflicts
# Generated 152/200 conflicts
# Generated 154/200 conflicts
# Generated 156/200 conflicts
# Generated 158/200 conflicts
# Generated 160/200 conflicts
# Generated 162/200 conflicts
# Generated 164/200 conflicts
# Generated 166/200 conflicts
# Generated 168/200 conflicts
# Generated 170/200 conflicts
# Generated 172/200 conflicts
# Generated 174/200 conflicts
# Generated 176/200 conflicts
# Generated 178/200 conflicts
# Generated 180/200 conflicts
# Generated 182/200 conflicts
# Generated 184/200 conflicts
# Generated 186/200 conflicts
# Generated 188/200 conflicts
# Generated 190/200 conflicts
# Generated 192/200 conflicts
# Generated 194/200 conflicts
# Generated 196/200 conflicts
# Generated 198/200 conflicts
# Generated 200/200 conflicts

# %%
# !python -m task1.analysis.evaluate_color_bias
# !python -m task1.analysis.evaluate_cue_conflicts
# !python -m task1.analysis.evaluate_translation
# !python -m task1.analysis.evaluate_patch_shuffle
# !python -m task1.analysis.run_representation_analysis
# !python -m task1.analysis.evaluate_bias
# Out:
# --- Color Bias: resnet50 ---
#   [clean          ]  acc=0.9480  Δacc=+0.0000  consistency=1.0000  f1=0.9481
#   [grayscale      ]  acc=0.9180  Δacc=-0.0300  consistency=0.9420  f1=0.9190
#   [hue_rotation   ]  acc=0.9280  Δacc=-0.0200  consistency=0.9600  f1=0.9277
#
# --- Color Bias: vit_b_16 ---
#   [clean          ]  acc=0.9740  Δacc=+0.0000  consistency=1.0000  f1=0.9741
#   [grayscale      ]  acc=0.9400  Δacc=-0.0340  consistency=0.9520  f1=0.9404
#   [hue_rotation   ]  acc=0.9420  Δacc=-0.0320  consistency=0.9500  f1=0.9420
#
# --- Color Bias: clip_vit_b_32 ---
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   [clean          ]  acc=0.9700  Δacc=+0.0000  consistency=1.0000  f1=0.9698
#   [grayscale      ]  acc=0.9240  Δacc=-0.0460  consistency=0.9180  f1=0.9236
#   [hue_rotation   ]  acc=0.9220  Δacc=-0.0480  consistency=0.9320  f1=0.9217
#
# Saved color-bias results to /kaggle/working/ATML-PA1/task1/results/color_bias.json
#   Loaded 200 cue-conflict images: 200 accepted, 0 rejected.
#
# --- Cue Conflicts: resnet50 ---
#   n_shape=22  n_texture=121  n_other=57  n_total=200
#   Shape Bias = 15.38%   Coverage = 71.50%
#
# --- Cue Conflicts: vit_b_16 ---
#   n_shape=60  n_texture=98  n_other=42  n_total=200
#   Shape Bias = 37.97%   Coverage = 79.00%
#
# --- Cue Conflicts: clip_vit_b_32 ---
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   n_shape=54  n_texture=57  n_other=89  n_total=200
#   Shape Bias = 48.65%   Coverage = 55.50%
#
# Saved cue-conflict results to /kaggle/working/ATML-PA1/task1/results/cue_conflicts.json
#
# --- Translation: resnet50 ---
#   δ= 0px  acc=0.9480  consistency=1.0000  Δacc=+0.0000
#   δ= 8px  acc=0.9460  consistency=0.9860  Δacc=-0.0020
#   δ=16px  acc=0.9415  consistency=0.9795  Δacc=-0.0065
#   δ=32px  acc=0.9350  consistency=0.9725  Δacc=-0.0130
#
# --- Translation: vit_b_16 ---
#   δ= 0px  acc=0.9740  consistency=1.0000  Δacc=+0.0000
#   δ= 8px  acc=0.9715  consistency=0.9845  Δacc=-0.0025
#   δ=16px  acc=0.9730  consistency=0.9890  Δacc=-0.0010
#   δ=32px  acc=0.9675  consistency=0.9835  Δacc=-0.0065
#
# --- Translation: clip_vit_b_32 ---
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   δ= 0px  acc=0.9700  consistency=1.0000  Δacc=+0.0000
#   δ= 8px  acc=0.9575  consistency=0.9685  Δacc=-0.0125
#   δ=16px  acc=0.9565  consistency=0.9655  Δacc=-0.0135
#   δ=32px  acc=0.9405  consistency=0.9635  Δacc=-0.0295
#
# Saved translation results to /kaggle/working/ATML-PA1/task1/results/translation.json
# Saved translation curve to /kaggle/working/ATML-PA1/task1/results/translation_curve.png
#
# --- Patch Shuffle: resnet50 ---
#   clean_acc=0.9480  shuffled_acc=0.8540  Δacc=-0.0940  consistency=0.8740  f1=0.8494
#
# --- Patch Shuffle: vit_b_16 ---
#   clean_acc=0.9740  shuffled_acc=0.9180  Δacc=-0.0560  consistency=0.9300  f1=0.9179
#
# --- Patch Shuffle: clip_vit_b_32 ---
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   clean_acc=0.9700  shuffled_acc=0.7800  Δacc=-0.1900  consistency=0.7860  f1=0.7779
#
# Saved patch-shuffle results to /kaggle/working/ATML-PA1/task1/results/patch_shuffle.json
# Found 200 accepted cue-conflict images.
#
# =======================================================
#   Backbone: resnet50
# =======================================================
#   Cosine stability [Grayscale] = 0.7876
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_resnet50_Grayscale.png
#   Cosine stability [Translation16] = 0.9516
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_resnet50_Translation16.png
#   Cosine stability [PatchShuffle] = 0.6923
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_resnet50_PatchShuffle.png
#   Cosine stability [CueConflict] = 0.2421  (vs. clean class prototype, N=200)
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_resnet50_CueConflict.png
#
# =======================================================
#   Backbone: vit_b_16
# =======================================================
#   Cosine stability [Grayscale] = 0.7232
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_vit_b_16_Grayscale.png
#   Cosine stability [Translation16] = 0.9716
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_vit_b_16_Translation16.png
#   Cosine stability [PatchShuffle] = 0.6167
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_vit_b_16_PatchShuffle.png
#   Cosine stability [CueConflict] = 0.1499  (vs. clean class prototype, N=200)
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_vit_b_16_CueConflict.png
#
# =======================================================
#   Backbone: clip_vit_b_32
# =======================================================
# /usr/local/lib/python3.12/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
#   Cosine stability [Grayscale] = 0.8852
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_clip_vit_b_32_Grayscale.png
#   Cosine stability [Translation16] = 0.9612
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_clip_vit_b_32_Translation16.png
#   Cosine stability [PatchShuffle] = 0.7358
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_clip_vit_b_32_PatchShuffle.png
#   Cosine stability [CueConflict] = 0.7229  (vs. clean class prototype, N=200)
# /kaggle/working/ATML-PA1/task1/analysis/run_representation_analysis.py:118: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab10", len(STL10_CLASSES))
#   Saved t-SNE -> /kaggle/working/ATML-PA1/task1/results/tsne_clip_vit_b_32_CueConflict.png
#
# Saved representation stability to /kaggle/working/ATML-PA1/task1/results/representation_stability.json
#
# === Cosine Stability Summary ===
# Model               Grayscale         Translation16     PatchShuffle      CueConflict
# resnet50            0.7876            0.9516            0.6923            0.2421
# vit_b_16            0.7232            0.9716            0.6167            0.1499
# clip_vit_b_32       0.8852            0.9612            0.7358            0.7229
#
# ───────────────────────────────────────────────────────
#   Clean Baseline
# ───────────────────────────────────────────────────────
#   resnet50_linear            acc=0.9540  f1=0.9540  conf=0.9087
#   vit_b_16_linear            acc=0.9740  f1=0.9741  conf=0.9618
#   clip_vit_b_32_linear       acc=0.9700  f1=0.9698  conf=0.4362
#   clip_zeroshot              acc=0.9320  f1=0.9305  conf=0.9211
#
# ───────────────────────────────────────────────────────
#   Color Bias
# ───────────────────────────────────────────────────────
#
#   resnet50
#     clean               acc=0.9480  Δacc=+0.0000  consistency=1.0000
#     grayscale           acc=0.9180  Δacc=-0.0300  consistency=0.9420
#     hue_rotation        acc=0.9280  Δacc=-0.0200  consistency=0.9600
#
#   vit_b_16
#     clean               acc=0.9740  Δacc=+0.0000  consistency=1.0000
#     grayscale           acc=0.9400  Δacc=-0.0340  consistency=0.9520
#     hue_rotation        acc=0.9420  Δacc=-0.0320  consistency=0.9500
#
#   clip_vit_b_32
#     clean               acc=0.9700  Δacc=+0.0000  consistency=1.0000
#     grayscale           acc=0.9240  Δacc=-0.0460  consistency=0.9180
#     hue_rotation        acc=0.9220  Δacc=-0.0480  consistency=0.9320
#
# ───────────────────────────────────────────────────────
#   Cue Conflicts
# ───────────────────────────────────────────────────────
#   resnet50              shape_bias=15.38%  coverage=71.50%  (n_shape=22  n_tex=121  n_other=57)
#   vit_b_16              shape_bias=37.97%  coverage=79.00%  (n_shape=60  n_tex=98  n_other=42)
#   clip_vit_b_32         shape_bias=48.65%  coverage=55.50%  (n_shape=54  n_tex=57  n_other=89)
#
# ───────────────────────────────────────────────────────
#   Translation
# ───────────────────────────────────────────────────────
#   resnet50
#     δ= 0px  acc=0.9480  consistency=1.0000
#     δ= 8px  acc=0.9460  consistency=0.9860
#     δ=16px  acc=0.9415  consistency=0.9795
#     δ=32px  acc=0.9350  consistency=0.9725
#   vit_b_16
#     δ= 0px  acc=0.9740  consistency=1.0000
#     δ= 8px  acc=0.9715  consistency=0.9845
#     δ=16px  acc=0.9730  consistency=0.9890
#     δ=32px  acc=0.9675  consistency=0.9835
#   clip_vit_b_32
#     δ= 0px  acc=0.9700  consistency=1.0000
#     δ= 8px  acc=0.9575  consistency=0.9685
#     δ=16px  acc=0.9565  consistency=0.9655
#     δ=32px  acc=0.9405  consistency=0.9635
#
# ───────────────────────────────────────────────────────
#   Patch Shuffle
# ───────────────────────────────────────────────────────
#   resnet50              clean=0.9480  shuffled=0.8540  Δacc=-0.0940  consistency=0.8740
#   vit_b_16              clean=0.9740  shuffled=0.9180  Δacc=-0.0560  consistency=0.9300
#   clip_vit_b_32         clean=0.9700  shuffled=0.7800  Δacc=-0.1900  consistency=0.7860

# %%
# !zip -r /kaggle/working/task1_results.zip task1/results/
from IPython.display import FileLink
FileLink('/kaggle/working/task1_results.zip')
# Out:
# updating: task1/results/ (stored 0%)
# updating: task1/results/translation_curve.png (deflated 11%)
# updating: task1/results/tsne_resnet50_CueConflict.png (deflated 15%)
# updating: task1/results/heads/ (stored 0%)
# updating: task1/results/heads/clip_vit_b_32_head.pt (deflated 14%)
# updating: task1/results/heads/vit_b_16_head.pt (deflated 11%)
# updating: task1/results/heads/resnet50_head.pt (deflated 9%)
# updating: task1/results/tsne_vit_b_16_PatchShuffle.png (deflated 8%)
# updating: task1/results/tsne_clip_vit_b_32_Grayscale.png (deflated 9%)
# updating: task1/results/representation_stability.json (deflated 57%)
# updating: task1/results/tsne_resnet50_Grayscale.png (deflated 8%)
# updating: task1/results/tsne_vit_b_16_Translation16.png (deflated 8%)
# updating: task1/results/patch_shuffle.json (deflated 63%)
# updating: task1/results/tsne_clip_vit_b_32_CueConflict.png (deflated 14%)
# updating: task1/results/tsne_clip_vit_b_32_Translation16.png (deflated 7%)
# updating: task1/results/tsne_resnet50_PatchShuffle.png (deflated 9%)
# updating: task1/results/cue_conflicts.json (deflated 92%)
# updating: task1/results/tsne_clip_vit_b_32_PatchShuffle.png (deflated 8%)
# updating: task1/results/clean_baseline.json (deflated 56%)
# updating: task1/results/color_bias.json (deflated 76%)
# updating: task1/results/tsne_vit_b_16_Grayscale.png (deflated 8%)
# updating: task1/results/tsne_vit_b_16_CueConflict.png (deflated 13%)
# updating: task1/results/tsne_resnet50_Translation16.png (deflated 8%)
# updating: task1/results/translation.json (deflated 84%)
# /kaggle/working/task1_results.zip

# %%
# !git pull
# Out:
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 3), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.14 KiB | 1.14 MiB/s, done.
# From https://github.com/syedmoazzamrazagilani/ATML-PA1
#    b742892..3e727c7  main       -> origin/main
# Updating b742892..3e727c7
# Fast-forward
#  task4/methods/manifold_mixup.py | 5 +++--
#  1 file changed, 3 insertions(+), 2 deletions(-)

# %%
# !python -m task4.methods.vanilla --method vanilla
# Out:
# [vanilla] device=cuda
# Epoch   1/100 | loss=2.0613  val_acc=0.3800  lr=0.09998
#   -> Saved best checkpoint (val_acc=0.3800)
# Epoch   2/100 | loss=1.4632  val_acc=0.5356  lr=0.09990
#   -> Saved best checkpoint (val_acc=0.5356)
# Epoch   3/100 | loss=1.1755  val_acc=0.5738  lr=0.09978
#   -> Saved best checkpoint (val_acc=0.5738)
# Epoch   4/100 | loss=0.9862  val_acc=0.6270  lr=0.09961
#   -> Saved best checkpoint (val_acc=0.6270)
# Epoch   5/100 | loss=0.8435  val_acc=0.6488  lr=0.09938
#   -> Saved best checkpoint (val_acc=0.6488)
# Epoch   6/100 | loss=0.7185  val_acc=0.7252  lr=0.09911
#   -> Saved best checkpoint (val_acc=0.7252)
# Epoch   7/100 | loss=0.6219  val_acc=0.7124  lr=0.09880
# Epoch   8/100 | loss=0.5745  val_acc=0.8128  lr=0.09843
#   -> Saved best checkpoint (val_acc=0.8128)
# Epoch   9/100 | loss=0.5301  val_acc=0.7792  lr=0.09801
# Epoch  10/100 | loss=0.5025  val_acc=0.7936  lr=0.09755
# Epoch  11/100 | loss=0.4829  val_acc=0.7606  lr=0.09704
# Epoch  12/100 | loss=0.4600  val_acc=0.7944  lr=0.09649
# Epoch  13/100 | loss=0.4433  val_acc=0.8226  lr=0.09589
#   -> Saved best checkpoint (val_acc=0.8226)
# Epoch  14/100 | loss=0.4284  val_acc=0.8262  lr=0.09524
#   -> Saved best checkpoint (val_acc=0.8262)
# Epoch  15/100 | loss=0.4219  val_acc=0.8022  lr=0.09455
# Epoch  16/100 | loss=0.4060  val_acc=0.7744  lr=0.09382
# Epoch  17/100 | loss=0.3988  val_acc=0.8430  lr=0.09304
#   -> Saved best checkpoint (val_acc=0.8430)
# Epoch  18/100 | loss=0.3854  val_acc=0.7942  lr=0.09222
# Epoch  19/100 | loss=0.3782  val_acc=0.8406  lr=0.09135
# Epoch  20/100 | loss=0.3676  val_acc=0.8478  lr=0.09045
#   -> Saved best checkpoint (val_acc=0.8478)
# Epoch  21/100 | loss=0.3560  val_acc=0.8206  lr=0.08951
# Epoch  22/100 | loss=0.3530  val_acc=0.8094  lr=0.08853
# Epoch  23/100 | loss=0.3457  val_acc=0.8596  lr=0.08751
#   -> Saved best checkpoint (val_acc=0.8596)
# Epoch  24/100 | loss=0.3407  val_acc=0.8466  lr=0.08645
# Epoch  25/100 | loss=0.3370  val_acc=0.8308  lr=0.08536
# Epoch  26/100 | loss=0.3251  val_acc=0.8610  lr=0.08423
#   -> Saved best checkpoint (val_acc=0.8610)
# Epoch  27/100 | loss=0.3212  val_acc=0.7964  lr=0.08307
# Epoch  28/100 | loss=0.3178  val_acc=0.8048  lr=0.08187
# Epoch  29/100 | loss=0.3087  val_acc=0.8562  lr=0.08065
# Epoch  30/100 | loss=0.3073  val_acc=0.7800  lr=0.07939
# Epoch  31/100 | loss=0.3031  val_acc=0.8476  lr=0.07810
# Epoch  32/100 | loss=0.2915  val_acc=0.8522  lr=0.07679
# Epoch  33/100 | loss=0.2902  val_acc=0.8424  lr=0.07545
# Epoch  34/100 | loss=0.2787  val_acc=0.7616  lr=0.07409
# Epoch  35/100 | loss=0.2792  val_acc=0.8544  lr=0.07270
# Epoch  36/100 | loss=0.2720  val_acc=0.8792  lr=0.07129
#   -> Saved best checkpoint (val_acc=0.8792)
# Epoch  37/100 | loss=0.2662  val_acc=0.8756  lr=0.06986
# Epoch  38/100 | loss=0.2702  val_acc=0.8654  lr=0.06841
# Epoch  39/100 | loss=0.2607  val_acc=0.8592  lr=0.06694
# Epoch  40/100 | loss=0.2542  val_acc=0.8438  lr=0.06545
# Epoch  41/100 | loss=0.2474  val_acc=0.8794  lr=0.06395
#   -> Saved best checkpoint (val_acc=0.8794)
# Epoch  42/100 | loss=0.2443  val_acc=0.8888  lr=0.06243
#   -> Saved best checkpoint (val_acc=0.8888)
# Epoch  43/100 | loss=0.2389  val_acc=0.8694  lr=0.06091
# Epoch  44/100 | loss=0.2356  val_acc=0.8732  lr=0.05937
# Epoch  45/100 | loss=0.2268  val_acc=0.8900  lr=0.05782
#   -> Saved best checkpoint (val_acc=0.8900)
# Epoch  46/100 | loss=0.2198  val_acc=0.8870  lr=0.05627
# Epoch  47/100 | loss=0.2186  val_acc=0.8872  lr=0.05471
# Epoch  48/100 | loss=0.2074  val_acc=0.8746  lr=0.05314
# Epoch  49/100 | loss=0.2085  val_acc=0.8848  lr=0.05157
# Epoch  50/100 | loss=0.2027  val_acc=0.8860  lr=0.05000
# Epoch  51/100 | loss=0.1954  val_acc=0.8828  lr=0.04843
# Epoch  52/100 | loss=0.1889  val_acc=0.8652  lr=0.04686
# Epoch  53/100 | loss=0.1890  val_acc=0.8906  lr=0.04529
#   -> Saved best checkpoint (val_acc=0.8906)
# Epoch  54/100 | loss=0.1770  val_acc=0.9024  lr=0.04373
#   -> Saved best checkpoint (val_acc=0.9024)
# Epoch  55/100 | loss=0.1666  val_acc=0.8984  lr=0.04218
# Epoch  56/100 | loss=0.1635  val_acc=0.8984  lr=0.04063
# Epoch  57/100 | loss=0.1639  val_acc=0.9010  lr=0.03909
# Epoch  58/100 | loss=0.1528  val_acc=0.8862  lr=0.03757
# Epoch  59/100 | loss=0.1455  val_acc=0.9010  lr=0.03605
# Epoch  60/100 | loss=0.1391  val_acc=0.8904  lr=0.03455
# Epoch  61/100 | loss=0.1346  val_acc=0.9022  lr=0.03306
# Epoch  62/100 | loss=0.1266  val_acc=0.8916  lr=0.03159
# Epoch  63/100 | loss=0.1234  val_acc=0.9072  lr=0.03014
#   -> Saved best checkpoint (val_acc=0.9072)
# Epoch  64/100 | loss=0.1126  val_acc=0.9074  lr=0.02871
#   -> Saved best checkpoint (val_acc=0.9074)
# Epoch  65/100 | loss=0.1114  val_acc=0.9120  lr=0.02730
#   -> Saved best checkpoint (val_acc=0.9120)
# Epoch  66/100 | loss=0.1021  val_acc=0.9090  lr=0.02591
# Epoch  67/100 | loss=0.0975  val_acc=0.9182  lr=0.02455
#   -> Saved best checkpoint (val_acc=0.9182)
# Epoch  68/100 | loss=0.0891  val_acc=0.9156  lr=0.02321
# Epoch  69/100 | loss=0.0849  val_acc=0.9202  lr=0.02190
#   -> Saved best checkpoint (val_acc=0.9202)
# Epoch  70/100 | loss=0.0781  val_acc=0.9154  lr=0.02061
# Epoch  71/100 | loss=0.0706  val_acc=0.9180  lr=0.01935
# Epoch  72/100 | loss=0.0629  val_acc=0.9104  lr=0.01813
# Epoch  73/100 | loss=0.0615  val_acc=0.9242  lr=0.01693
#   -> Saved best checkpoint (val_acc=0.9242)
# Epoch  74/100 | loss=0.0494  val_acc=0.9208  lr=0.01577
# Epoch  75/100 | loss=0.0467  val_acc=0.9300  lr=0.01464
#   -> Saved best checkpoint (val_acc=0.9300)
# Epoch  76/100 | loss=0.0407  val_acc=0.9336  lr=0.01355
#   -> Saved best checkpoint (val_acc=0.9336)
# Epoch  77/100 | loss=0.0337  val_acc=0.9364  lr=0.01249
#   -> Saved best checkpoint (val_acc=0.9364)
# Epoch  78/100 | loss=0.0336  val_acc=0.9372  lr=0.01147
#   -> Saved best checkpoint (val_acc=0.9372)
# Epoch  79/100 | loss=0.0227  val_acc=0.9358  lr=0.01049
# Epoch  80/100 | loss=0.0217  val_acc=0.9322  lr=0.00955
# Epoch  81/100 | loss=0.0156  val_acc=0.9424  lr=0.00865
#   -> Saved best checkpoint (val_acc=0.9424)
# Epoch  82/100 | loss=0.0130  val_acc=0.9376  lr=0.00778
# Epoch  83/100 | loss=0.0096  val_acc=0.9402  lr=0.00696
# Epoch  84/100 | loss=0.0095  val_acc=0.9480  lr=0.00618
#   -> Saved best checkpoint (val_acc=0.9480)
# Epoch  85/100 | loss=0.0068  val_acc=0.9492  lr=0.00545
#   -> Saved best checkpoint (val_acc=0.9492)
# Epoch  86/100 | loss=0.0063  val_acc=0.9472  lr=0.00476
# Epoch  87/100 | loss=0.0046  val_acc=0.9494  lr=0.00411
#   -> Saved best checkpoint (val_acc=0.9494)
# Epoch  88/100 | loss=0.0043  val_acc=0.9520  lr=0.00351
#   -> Saved best checkpoint (val_acc=0.9520)
# Epoch  89/100 | loss=0.0039  val_acc=0.9524  lr=0.00296
#   -> Saved best checkpoint (val_acc=0.9524)
# Epoch  90/100 | loss=0.0031  val_acc=0.9498  lr=0.00245
# Epoch  91/100 | loss=0.0031  val_acc=0.9490  lr=0.00199
# Epoch  92/100 | loss=0.0030  val_acc=0.9516  lr=0.00157
# Epoch  93/100 | loss=0.0028  val_acc=0.9508  lr=0.00120
# Epoch  94/100 | loss=0.0025  val_acc=0.9494  lr=0.00089
# Epoch  95/100 | loss=0.0026  val_acc=0.9498  lr=0.00062
# Epoch  96/100 | loss=0.0026  val_acc=0.9526  lr=0.00039
#   -> Saved best checkpoint (val_acc=0.9526)
# Epoch  97/100 | loss=0.0025  val_acc=0.9516  lr=0.00022
# Epoch  98/100 | loss=0.0024  val_acc=0.9518  lr=0.00010
# Epoch  99/100 | loss=0.0024  val_acc=0.9504  lr=0.00002
# Epoch 100/100 | loss=0.0022  val_acc=0.9512  lr=0.00000
#
# Best val_acc=0.9526 at epoch 96
# Checkpoint saved to task4/checkpoints/vanilla_best.pth
# History saved to task4/results/vanilla_history.json

# %%
# !python -m task4.methods.vanilla --method gcsc
# Out:
# [gcsc] device=cuda
# Epoch   1/100 | loss=2.2964  val_acc=0.3242  lr=0.09998
#   -> Saved best checkpoint (val_acc=0.3242)
# Epoch   2/100 | loss=1.7061  val_acc=0.4496  lr=0.09990
#   -> Saved best checkpoint (val_acc=0.4496)
# Epoch   3/100 | loss=1.4191  val_acc=0.5388  lr=0.09978
#   -> Saved best checkpoint (val_acc=0.5388)
# Epoch   4/100 | loss=1.1962  val_acc=0.6360  lr=0.09961
#   -> Saved best checkpoint (val_acc=0.6360)
# Epoch   5/100 | loss=1.0290  val_acc=0.5980  lr=0.09938
# Epoch   6/100 | loss=0.9076  val_acc=0.7222  lr=0.09911
#   -> Saved best checkpoint (val_acc=0.7222)
# Epoch   7/100 | loss=0.8004  val_acc=0.7360  lr=0.09880
#   -> Saved best checkpoint (val_acc=0.7360)
# Epoch   8/100 | loss=0.7363  val_acc=0.7834  lr=0.09843
#   -> Saved best checkpoint (val_acc=0.7834)
# Epoch   9/100 | loss=0.6957  val_acc=0.7346  lr=0.09801
# Epoch  10/100 | loss=0.6576  val_acc=0.7864  lr=0.09755
#   -> Saved best checkpoint (val_acc=0.7864)
# Epoch  11/100 | loss=0.6385  val_acc=0.7684  lr=0.09704
# Epoch  12/100 | loss=0.6119  val_acc=0.7992  lr=0.09649
#   -> Saved best checkpoint (val_acc=0.7992)
# Epoch  13/100 | loss=0.5984  val_acc=0.8260  lr=0.09589
#   -> Saved best checkpoint (val_acc=0.8260)
# Epoch  14/100 | loss=0.5806  val_acc=0.7818  lr=0.09524
# Epoch  15/100 | loss=0.5644  val_acc=0.8040  lr=0.09455
# Epoch  16/100 | loss=0.5565  val_acc=0.7998  lr=0.09382
# Epoch  17/100 | loss=0.5382  val_acc=0.8068  lr=0.09304
# Epoch  18/100 | loss=0.5315  val_acc=0.8524  lr=0.09222
#   -> Saved best checkpoint (val_acc=0.8524)
# Epoch  19/100 | loss=0.5197  val_acc=0.8418  lr=0.09135
# Epoch  20/100 | loss=0.5164  val_acc=0.8540  lr=0.09045
#   -> Saved best checkpoint (val_acc=0.8540)
# Epoch  21/100 | loss=0.5052  val_acc=0.8012  lr=0.08951
# Epoch  22/100 | loss=0.4998  val_acc=0.8248  lr=0.08853
# Epoch  23/100 | loss=0.4948  val_acc=0.8228  lr=0.08751
# Epoch  24/100 | loss=0.4848  val_acc=0.8426  lr=0.08645
# Epoch  25/100 | loss=0.4777  val_acc=0.8482  lr=0.08536
# Epoch  26/100 | loss=0.4714  val_acc=0.8396  lr=0.08423
# Epoch  27/100 | loss=0.4673  val_acc=0.8486  lr=0.08307
# Epoch  28/100 | loss=0.4600  val_acc=0.8430  lr=0.08187
# Epoch  29/100 | loss=0.4538  val_acc=0.8484  lr=0.08065
# Epoch  30/100 | loss=0.4468  val_acc=0.8224  lr=0.07939
# Epoch  31/100 | loss=0.4444  val_acc=0.8414  lr=0.07810
# Epoch  32/100 | loss=0.4355  val_acc=0.8586  lr=0.07679
#   -> Saved best checkpoint (val_acc=0.8586)
# Epoch  33/100 | loss=0.4340  val_acc=0.8610  lr=0.07545
#   -> Saved best checkpoint (val_acc=0.8610)
# Epoch  34/100 | loss=0.4280  val_acc=0.8292  lr=0.07409
# Epoch  35/100 | loss=0.4204  val_acc=0.8474  lr=0.07270
# Epoch  36/100 | loss=0.4158  val_acc=0.8602  lr=0.07129
# Epoch  37/100 | loss=0.4043  val_acc=0.8602  lr=0.06986
# Epoch  38/100 | loss=0.4037  val_acc=0.8692  lr=0.06841
#   -> Saved best checkpoint (val_acc=0.8692)
# Epoch  39/100 | loss=0.3945  val_acc=0.8612  lr=0.06694
# Epoch  40/100 | loss=0.3984  val_acc=0.8764  lr=0.06545
#   -> Saved best checkpoint (val_acc=0.8764)
# Epoch  41/100 | loss=0.3796  val_acc=0.8548  lr=0.06395
# Epoch  42/100 | loss=0.3795  val_acc=0.8698  lr=0.06243
# Epoch  43/100 | loss=0.3813  val_acc=0.8822  lr=0.06091
#   -> Saved best checkpoint (val_acc=0.8822)
# Epoch  44/100 | loss=0.3706  val_acc=0.8632  lr=0.05937
# Epoch  45/100 | loss=0.3689  val_acc=0.8930  lr=0.05782
#   -> Saved best checkpoint (val_acc=0.8930)
# Epoch  46/100 | loss=0.3604  val_acc=0.8846  lr=0.05627
# Epoch  47/100 | loss=0.3571  val_acc=0.8814  lr=0.05471
# Epoch  48/100 | loss=0.3411  val_acc=0.8776  lr=0.05314
# Epoch  49/100 | loss=0.3400  val_acc=0.8890  lr=0.05157
# Epoch  50/100 | loss=0.3349  val_acc=0.8830  lr=0.05000
# Epoch  51/100 | loss=0.3278  val_acc=0.8750  lr=0.04843
# Epoch  52/100 | loss=0.3228  val_acc=0.8968  lr=0.04686
#   -> Saved best checkpoint (val_acc=0.8968)
# Epoch  53/100 | loss=0.3122  val_acc=0.8864  lr=0.04529
# Epoch  54/100 | loss=0.3115  val_acc=0.8956  lr=0.04373
# Epoch  55/100 | loss=0.3028  val_acc=0.9046  lr=0.04218
#   -> Saved best checkpoint (val_acc=0.9046)
# Epoch  56/100 | loss=0.2949  val_acc=0.9062  lr=0.04063
#   -> Saved best checkpoint (val_acc=0.9062)
# Epoch  57/100 | loss=0.2886  val_acc=0.8910  lr=0.03909
# Epoch  58/100 | loss=0.2840  val_acc=0.8956  lr=0.03757
# Epoch  59/100 | loss=0.2699  val_acc=0.8830  lr=0.03605
# Epoch  60/100 | loss=0.2661  val_acc=0.9018  lr=0.03455
# Epoch  61/100 | loss=0.2610  val_acc=0.8966  lr=0.03306
# Epoch  62/100 | loss=0.2555  val_acc=0.9020  lr=0.03159
# Epoch  63/100 | loss=0.2488  val_acc=0.9078  lr=0.03014
#   -> Saved best checkpoint (val_acc=0.9078)
# Epoch  64/100 | loss=0.2403  val_acc=0.9068  lr=0.02871
# Epoch  65/100 | loss=0.2314  val_acc=0.9194  lr=0.02730
#   -> Saved best checkpoint (val_acc=0.9194)
# Epoch  66/100 | loss=0.2257  val_acc=0.9158  lr=0.02591
# Epoch  67/100 | loss=0.2126  val_acc=0.9236  lr=0.02455
#   -> Saved best checkpoint (val_acc=0.9236)
# Epoch  68/100 | loss=0.2080  val_acc=0.9172  lr=0.02321
# Epoch  69/100 | loss=0.1992  val_acc=0.9292  lr=0.02190
#   -> Saved best checkpoint (val_acc=0.9292)
# Epoch  70/100 | loss=0.1944  val_acc=0.9238  lr=0.02061
# Epoch  71/100 | loss=0.1838  val_acc=0.9148  lr=0.01935
# Epoch  72/100 | loss=0.1760  val_acc=0.9182  lr=0.01813
# Epoch  73/100 | loss=0.1663  val_acc=0.9274  lr=0.01693
# Epoch  74/100 | loss=0.1591  val_acc=0.9316  lr=0.01577
#   -> Saved best checkpoint (val_acc=0.9316)
# Epoch  75/100 | loss=0.1511  val_acc=0.9286  lr=0.01464
# Epoch  76/100 | loss=0.1383  val_acc=0.9332  lr=0.01355
#   -> Saved best checkpoint (val_acc=0.9332)
# Epoch  77/100 | loss=0.1289  val_acc=0.9412  lr=0.01249
#   -> Saved best checkpoint (val_acc=0.9412)
# Epoch  78/100 | loss=0.1232  val_acc=0.9288  lr=0.01147
# Epoch  79/100 | loss=0.1182  val_acc=0.9338  lr=0.01049
# Epoch  80/100 | loss=0.1072  val_acc=0.9410  lr=0.00955
# Epoch  81/100 | loss=0.1012  val_acc=0.9444  lr=0.00865
#   -> Saved best checkpoint (val_acc=0.9444)
# Epoch  82/100 | loss=0.0927  val_acc=0.9460  lr=0.00778
#   -> Saved best checkpoint (val_acc=0.9460)
# Epoch  83/100 | loss=0.0852  val_acc=0.9410  lr=0.00696
# Epoch  84/100 | loss=0.0781  val_acc=0.9486  lr=0.00618
#   -> Saved best checkpoint (val_acc=0.9486)
# Epoch  85/100 | loss=0.0728  val_acc=0.9450  lr=0.00545
# Epoch  86/100 | loss=0.0667  val_acc=0.9500  lr=0.00476
#   -> Saved best checkpoint (val_acc=0.9500)
# Epoch  87/100 | loss=0.0616  val_acc=0.9484  lr=0.00411
# Epoch  88/100 | loss=0.0577  val_acc=0.9514  lr=0.00351
#   -> Saved best checkpoint (val_acc=0.9514)
# Epoch  89/100 | loss=0.0494  val_acc=0.9500  lr=0.00296
# Epoch  90/100 | loss=0.0478  val_acc=0.9556  lr=0.00245
#   -> Saved best checkpoint (val_acc=0.9556)
# Epoch  91/100 | loss=0.0448  val_acc=0.9556  lr=0.00199
# Epoch  92/100 | loss=0.0420  val_acc=0.9584  lr=0.00157
#   -> Saved best checkpoint (val_acc=0.9584)
# Epoch  93/100 | loss=0.0394  val_acc=0.9552  lr=0.00120
# Epoch  94/100 | loss=0.0373  val_acc=0.9580  lr=0.00089
# Epoch  95/100 | loss=0.0348  val_acc=0.9580  lr=0.00062
# Epoch  96/100 | loss=0.0337  val_acc=0.9568  lr=0.00039
# Epoch  97/100 | loss=0.0327  val_acc=0.9578  lr=0.00022
# Epoch  98/100 | loss=0.0310  val_acc=0.9590  lr=0.00010
#   -> Saved best checkpoint (val_acc=0.9590)
# Epoch  99/100 | loss=0.0304  val_acc=0.9584  lr=0.00002

# %%
# !python -m task4.extract_outputs --method vanilla
# !python -m task4.extract_outputs --method gcsc
# Out:
#   Extracting vanilla / cifar10_train …
#     saved torch.Size([45000, 512]) → task4/cache/vanilla_cifar10_train.pt
#   Extracting vanilla / cifar10_val …
#     saved torch.Size([5000, 512]) → task4/cache/vanilla_cifar10_val.pt
#   Extracting vanilla / cifar10_test …
#     saved torch.Size([10000, 512]) → task4/cache/vanilla_cifar10_test.pt
# 100%|█████████████████████████████████████████| 169M/169M [26:26<00:00, 107kB/s]
# [CIFAR-100 unknowns] near=800  far=800  total=1600
#   Extracting vanilla / cifar100_near …
#     saved torch.Size([800, 512]) → task4/cache/vanilla_cifar100_near.pt
#   Extracting vanilla / cifar100_far …
#     saved torch.Size([800, 512]) → task4/cache/vanilla_cifar100_far.pt
#
# All outputs cached for [vanilla].
#   Extracting gcsc / cifar10_train …
#     saved torch.Size([45000, 512]) → task4/cache/gcsc_cifar10_train.pt
#   Extracting gcsc / cifar10_val …
#     saved torch.Size([5000, 512]) → task4/cache/gcsc_cifar10_val.pt
#   Extracting gcsc / cifar10_test …
#     saved torch.Size([10000, 512]) → task4/cache/gcsc_cifar10_test.pt
# [CIFAR-100 unknowns] near=800  far=800  total=1600
#   Extracting gcsc / cifar100_near …
#     saved torch.Size([800, 512]) → task4/cache/gcsc_cifar100_near.pt
#   Extracting gcsc / cifar100_far …
#     saved torch.Size([800, 512]) → task4/cache/gcsc_cifar100_far.pt
#
# All outputs cached for [gcsc].

# %%
# !python -m task4.methods.proser
# Out:
# [PROSER] device=cuda
# Epoch   1/50 | ce=0.1051  cph=0.2672  dph=0.6902  val_acc=0.9372
#   -> Saved best checkpoint (val_acc=0.9372)
# Epoch   2/50 | ce=0.1079  cph=0.1401  dph=0.6266  val_acc=0.9394
#   -> Saved best checkpoint (val_acc=0.9394)
# Epoch   3/50 | ce=0.1076  cph=0.1354  dph=0.6060  val_acc=0.9388
# Epoch   4/50 | ce=0.1059  cph=0.1337  dph=0.5897  val_acc=0.9370
# Epoch   5/50 | ce=0.1060  cph=0.1344  dph=0.5674  val_acc=0.9358
# Epoch   6/50 | ce=0.0935  cph=0.1331  dph=0.4261  val_acc=0.9256
# Epoch   7/50 | ce=0.0621  cph=0.0900  dph=0.2886  val_acc=0.8312
# Epoch   8/50 | ce=0.0523  cph=0.0756  dph=0.2783  val_acc=0.8958
# Epoch   9/50 | ce=0.0411  cph=0.0566  dph=0.2413  val_acc=0.8738
# Epoch  10/50 | ce=0.0466  cph=0.0602  dph=0.2828  val_acc=0.8618
# Epoch  11/50 | ce=0.0378  cph=0.0492  dph=0.2475  val_acc=0.8476
# Epoch  12/50 | ce=0.0330  cph=0.0459  dph=0.2318  val_acc=0.8984
# Epoch  13/50 | ce=0.0345  cph=0.0445  dph=0.2333  val_acc=0.9294
# Epoch  14/50 | ce=0.0355  cph=0.0422  dph=0.2381  val_acc=0.8488
# Epoch  15/50 | ce=0.0311  cph=0.0358  dph=0.2217  val_acc=0.9270
# Epoch  23/50 | ce=0.0189  cph=0.0220  dph=0.1867  val_acc=0.6722
# Epoch  24/50 | ce=0.0256  cph=0.0278  dph=0.2083  val_acc=0.8800
# Epoch  25/50 | ce=0.0208  cph=0.0211  dph=0.1891  val_acc=0.8334
# Epoch  26/50 | ce=0.0185  cph=0.0203  dph=0.1859  val_acc=0.8528
# Epoch  27/50 | ce=0.0169  cph=0.0182  dph=0.1865  val_acc=0.7770
# Epoch  28/50 | ce=0.0175  cph=0.0191  dph=0.1785  val_acc=0.8106
# Epoch  30/50 | ce=0.0157  cph=0.0184  dph=0.1887  val_acc=0.8360
# Epoch  31/50 | ce=0.0126  cph=0.0152  dph=0.1799  val_acc=0.7938
# Epoch  38/50 | ce=0.0107  cph=0.0130  dph=0.1739  val_acc=0.7652
# Epoch  43/50 | ce=0.0089  cph=0.0119  dph=0.1733  val_acc=0.8072
# Epoch  44/50 | ce=0.0105  cph=0.0118  dph=0.1774  val_acc=0.7954
# Epoch  45/50 | ce=0.0101  cph=0.0125  dph=0.1724  val_acc=0.8466
# Epoch  46/50 | ce=0.0088  cph=0.0120  dph=0.1720  val_acc=0.7942
# Epoch  47/50 | ce=0.0094  cph=0.0124  dph=0.1717  val_acc=0.7998
# Epoch  48/50 | ce=0.0096  cph=0.0115  dph=0.1748  val_acc=0.7888
# Epoch  49/50 | ce=0.0087  cph=0.0125  dph=0.1767  val_acc=0.8234
# Epoch  50/50 | ce=0.0105  cph=0.0127  dph=0.1701  val_acc=0.7824
#
# History saved to task4/results/proser_history.json
# Best val_acc=0.9394

# %%
# !python -m task4.data.make_splits
# Out:
# Saved splits → task4/results/cifar10_splits_seed6304.json
#   train=45000  val=5000

# %%
# !python -m task4.extract_outputs --method vanilla
# !python -m task4.extract_outputs --method gcsc
# !python -m task4.extract_outputs --method proser
# Out:
#   Extracting vanilla / cifar10_train …
#     saved torch.Size([45000, 512]) → task4/cache/vanilla_cifar10_train.pt
#   Extracting vanilla / cifar10_val …
#     saved torch.Size([5000, 512]) → task4/cache/vanilla_cifar10_val.pt
#   Extracting vanilla / cifar10_test …
#     saved torch.Size([10000, 512]) → task4/cache/vanilla_cifar10_test.pt
# [CIFAR-100 unknowns] near=800  far=800  total=1600
#   Extracting vanilla / cifar100_near …
#     saved torch.Size([800, 512]) → task4/cache/vanilla_cifar100_near.pt
#   Extracting vanilla / cifar100_far …
#     saved torch.Size([800, 512]) → task4/cache/vanilla_cifar100_far.pt
#
# All outputs cached for [vanilla].
#   Extracting gcsc / cifar10_train …
#     saved torch.Size([45000, 512]) → task4/cache/gcsc_cifar10_train.pt
#   Extracting gcsc / cifar10_val …
#     saved torch.Size([5000, 512]) → task4/cache/gcsc_cifar10_val.pt
#   Extracting gcsc / cifar10_test …
#     saved torch.Size([10000, 512]) → task4/cache/gcsc_cifar10_test.pt
# [CIFAR-100 unknowns] near=800  far=800  total=1600
#   Extracting gcsc / cifar100_near …
#     saved torch.Size([800, 512]) → task4/cache/gcsc_cifar100_near.pt
#   Extracting gcsc / cifar100_far …
#     saved torch.Size([800, 512]) → task4/cache/gcsc_cifar100_far.pt
#
# All outputs cached for [gcsc].
#   Extracting proser / cifar10_train …
#     saved torch.Size([45000, 512]) → task4/cache/proser_cifar10_train.pt
#   Extracting proser / cifar10_val …
#     saved torch.Size([5000, 512]) → task4/cache/proser_cifar10_val.pt
#   Extracting proser / cifar10_test …
#     saved torch.Size([10000, 512]) → task4/cache/proser_cifar10_test.pt
# [CIFAR-100 unknowns] near=800  far=800  total=1600
#   Extracting proser / cifar100_near …
#     saved torch.Size([800, 512]) → task4/cache/proser_cifar100_near.pt
#   Extracting proser / cifar100_far …
#     saved torch.Size([800, 512]) → task4/cache/proser_cifar100_far.pt
#
# All outputs cached for [proser].

# %%
# !python -m task4.evaluate_osr
# Out:
# ======================================================================
# TABLE 1: Post-hoc scores on Vanilla model
# ======================================================================
# Score          |  AUROC Near | AUROC Far | AUROC All |  Acc@95TPR |  Rej Near |  Rej Far |  FPR@95 Near | FPR@95 Far
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# MSP            |      0.8116 |    0.8991 |    0.8553 |     0.9447 |    0.3038 |   0.4550 |       0.6963 |     0.5450
# MLS            |      0.7907 |    0.8944 |    0.8426 |     0.9476 |    0.3275 |   0.5387 |       0.6725 |     0.4612
# Energy         |      0.7909 |    0.8951 |    0.8430 |     0.9463 |    0.3337 |   0.5537 |       0.6663 |     0.4462
# Mahalanobis    |      0.7888 |    0.9130 |    0.8509 |     0.9436 |    0.3050 |   0.5138 |       0.6950 |     0.4863
#
# Vanilla CSA (CIFAR-10 test): 0.9465
#
# ======================================================================
# TABLE 2: Model comparison  (MLS + PROSER placeholder score)
# ======================================================================
# Model+Score            |    CSA |  AUROC Near | AUROC Far | AUROC All |  Rej Near |  Rej Far |  FPR@95 Near
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
# vanilla_MLS            | 0.9465 |      0.7907 |    0.8944 |    0.8426 |    0.3275 |   0.5387 |       0.6725
# gcsc_MLS               | 0.9509 |      0.8085 |    0.9127 |    0.8606 |    0.3588 |   0.6125 |       0.6412
# proser_MLS             | 0.9360 |      0.7995 |    0.8646 |    0.8321 |    0.3400 |   0.5012 |       0.6600
# [CIFAR-100 unknowns] near=800  far=800  total=1600
# proser_PROSER          | 0.9360 |      0.7150 |    0.7813 |    0.7481 |    0.2812 |   0.3663 |       0.7188
#
# Generating score-distribution / ROC figure …
# Saved score figure → task4/results/osr_score_figure.png
#
# ======================================================================
# FAILURE ANALYSIS: MLS on Vanilla  (incorrectly accepted unknowns)
# ======================================================================
#
# ────────────────────────────────────────────────────────────
#   Near-Unknown Failures (MLS, Vanilla)  (6 cases)
# ────────────────────────────────────────────────────────────
#   Unknown class        Pred (CIFAR-10)       Score   Threshold
#   fox                  cat                  -11.5020     -5.8112
#   fox                  deer                 -11.3454     -5.8112
#   wolf                 cat                  -11.1440     -5.8112
#   tractor              truck                -11.0105     -5.8112
#   bus                  truck                -11.0018     -5.8112
#   fox                  cat                  -10.9548     -5.8112
#
# ────────────────────────────────────────────────────────────
#   Far-Unknown Failures  (MLS, Vanilla)  (6 cases)
# ────────────────────────────────────────────────────────────
#   Unknown class        Pred (CIFAR-10)       Score   Threshold
#   keyboard             bird                 -13.5959     -5.8112
#   sunflower            bird                 -11.6173     -5.8112
#   sunflower            bird                 -11.1124     -5.8112
#   bowl                 ship                 -10.7629     -5.8112
#   clock                truck                -10.5785     -5.8112
#   sunflower            bird                 -10.5763     -5.8112
# Training curves saved → task4/results/training_curves.png
#
# All OSR results saved → task4/results/osr_results.json
