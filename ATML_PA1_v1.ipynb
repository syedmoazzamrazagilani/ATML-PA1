# %%
# !git clone https://github.com/syedmoazzamrazagilani/ATML-PA1.git
# Out:
# Cloning into 'ATML-PA1'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (230/230), done.
# remote: Compressing objects: 100% (208/208), done.
# remote: Total 230 (delta 91), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (230/230), 80.83 KiB | 3.67 MiB/s, done.
# Resolving deltas: 100% (91/91), done.

# %%
# %cd ATML-PA1
# !pip install -r requirements.txt
# Out:
# /content/ATML-PA1
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 1)) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 2)) (0.26.0+cu128)
# Collecting open-clip-torch>=2.20.0 (from -r requirements.txt (line 3))
#   Downloading open_clip_torch-3.3.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 4)) (2.1.3)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 5)) (1.6.1)
# Requirement already satisfied: timm>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 6)) (1.0.29)
# Requirement already satisfied: pillow>=9.5.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 7)) (11.3.0)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: umap-learn>=0.5.3 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 9)) (0.5.12)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: PyYAML>=6.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 11)) (6.0.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->-r requirements.txt (line 1)) (12.8.90)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (2025.11.3)
# Collecting ftfy (from open-clip-torch>=2.20.0->-r requirements.txt (line 3))
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.13/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.29.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.13/dist-packages (from open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.8.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.13/dist-packages (from umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.13/dist-packages (from umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.7.0->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn>=1.2.0->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.13/dist-packages (from numba>=0.51.2->umap-learn>=0.5.3->-r requirements.txt (line 9)) (0.44.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->-r requirements.txt (line 10)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.13/dist-packages (from ftfy->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub->open-clip-torch>=2.20.0->-r requirements.txt (line 3)) (0.16.0)
# Downloading open_clip_torch-3.3.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 47.1 MB/s eta 0:00:00
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: ftfy, open-clip-torch
# Successfully installed ftfy-6.3.1 open-clip-torch-3.3.0

# %%
# !python -m task1.data.make_subset
# Out:
# 100% 2.64G/2.64G [16:19<00:00, 2.70MB/s]
# Splits saved to /content/ATML-PA1/task1/data_cache/stl10_splits_seed6304.json
# Train samples: 4000, Val samples: 1000, Test subset: 500

# %%
# !python -m task1.data.make_cue_conflicts
# Out:
# Loading VGG19 for Style Transfer...
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100% 548M/548M [00:07<00:00, 76.4MB/s]
# Generated 2/200 conflicts
# Generated 4/200 conflicts
# Generated 6/200 conflicts
# Generated 8/200 conflicts
# Generated 10/200 conflicts
# Generated 12/200 conflicts
# Generated 14/200 conflicts
# Generated 16/200 conflicts
# Generated 18/200 conflicts
# Generated 20/200 conflicts
# Generated 22/200 conflicts
# Generated 24/200 conflicts
# Generated 26/200 conflicts
# Generated 28/200 conflicts
# Generated 30/200 conflicts
# Generated 32/200 conflicts
# Generated 34/200 conflicts
# Generated 36/200 conflicts
# Generated 38/200 conflicts
# Generated 40/200 conflicts
# Generated 42/200 conflicts
# Generated 44/200 conflicts
# Generated 46/200 conflicts
# Generated 48/200 conflicts
# Generated 50/200 conflicts
# Generated 52/200 conflicts
# Generated 54/200 conflicts
# Generated 56/200 conflicts
# Generated 58/200 conflicts
# Generated 60/200 conflicts
# Generated 62/200 conflicts
# Generated 64/200 conflicts
# Generated 66/200 conflicts
# Generated 68/200 conflicts
# Generated 70/200 conflicts
# Generated 72/200 conflicts
# Generated 74/200 conflicts
# Generated 76/200 conflicts
# Generated 78/200 conflicts
# Generated 80/200 conflicts
# Generated 82/200 conflicts
# Generated 84/200 conflicts
# Generated 86/200 conflicts
# Generated 88/200 conflicts
# Generated 90/200 conflicts
# Generated 92/200 conflicts
# Generated 94/200 conflicts
# Generated 96/200 conflicts
# Generated 98/200 conflicts
# Generated 100/200 conflicts
# Generated 102/200 conflicts
# Generated 104/200 conflicts
# Generated 106/200 conflicts
# Generated 108/200 conflicts
# Generated 110/200 conflicts
# Generated 112/200 conflicts
# Generated 114/200 conflicts
# Generated 116/200 conflicts
# Generated 118/200 conflicts
# Generated 120/200 conflicts
# Generated 122/200 conflicts
# Generated 124/200 conflicts
# Generated 126/200 conflicts
# Generated 128/200 conflicts
# Generated 130/200 conflicts
# Generated 132/200 conflicts
# Generated 134/200 conflicts
# Generated 136/200 conflicts
# Generated 138/200 conflicts
# Generated 140/200 conflicts
# Generated 142/200 conflicts
# Generated 144/200 conflicts
# Generated 146/200 conflicts
# Generated 148/200 conflicts
# Generated 150/200 conflicts
# Generated 152/200 conflicts
# Generated 154/200 conflicts
# Generated 156/200 conflicts
# Generated 158/200 conflicts
# Generated 160/200 conflicts
# Generated 162/200 conflicts
# Generated 164/200 conflicts
# Generated 166/200 conflicts
# Generated 168/200 conflicts
# Generated 170/200 conflicts
# Generated 172/200 conflicts
# Generated 174/200 conflicts
# Generated 176/200 conflicts
# Generated 178/200 conflicts
# Generated 180/200 conflicts
# Generated 182/200 conflicts
# Generated 184/200 conflicts
# Generated 186/200 conflicts
# Generated 188/200 conflicts
# Generated 190/200 conflicts
# Generated 192/200 conflicts
# Generated 194/200 conflicts
# Generated 196/200 conflicts
# Generated 198/200 conflicts
# Generated 200/200 conflicts

# %%
# !git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !python -m task1.scripts.run_task1
# Out:
# --- Processing resnet50 ---
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 204MB/s]
# Early stopping at epoch 12
# resnet50 Linear Head -> Acc: 0.9580, F1: 0.9581, Conf: 0.9321
#
# --- Processing vit_b_16 ---
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100% 330M/330M [00:06<00:00, 57.6MB/s]
# Early stopping at epoch 14
# vit_b_16 Linear Head -> Acc: 0.9780, F1: 0.9780, Conf: 0.9771
#
# --- Processing clip_vit_b_32 ---
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# open_clip_model.safetensors: downloading bytes:  71% 432M/605M [00:02<00:00, 212MB/s, 37.7MB/s  ]
# open_clip_model.safetensors: reconstructing file:  44% 268M/605M [00:06<00:07, 44.0MB/s]
# open_clip_model.safetensors: downloading bytes: 100% 432M/432M [00:10<00:00, 40.8MB/s, 38.3MB/s  ]
# open_clip_model.safetensors: reconstructing file: 100% 605M/605M [00:10<00:00, 57.2MB/s, 43.4MB/s  ]
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# Early stopping at epoch 11
# clip_vit_b_32 Linear Head -> Acc: 0.9720, F1: 0.9719, Conf: 0.6044
# Evaluating Zero-Shot CLIP...
# CLIP Zero-Shot -> Acc: 0.9320, F1: 0.9305, Conf: 0.9211
# Clean baseline results saved to /content/ATML-PA1/task1/results/clean_baseline.json

# %%
# !git pull
# Out:
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 11.32 KiB | 1.13 MiB/s, done.
# From https://github.com/syedmoazzamrazagilani/ATML-PA1
#    a289371..1dfab51  main       -> origin/main
# Updating a289371..1dfab51
# Fast-forward
#  task2/controlled_study.py | 251 ++++++++++++++++++++++++++++++
#  task2/evaluate_final.py   | 387 ++++++++++++++++++++++++++++++++++------------
#  task2/train.py            | 193 ++++++++++++++++-------
#  3 files changed, 675 insertions(+), 156 deletions(-)
#  create mode 100644 task2/controlled_study.py

# %%
# !python -m task1.analysis.evaluate_bias
# Out:
# --- Running Interventions on resnet50 ---
# Quickly reloading linear head weights...
# [grayscale] Accuracy: 0.8860
# [hue_rotation] Accuracy: 0.9220
# [patch_shuffle] Accuracy: 0.8540
# [translation_8px] Avg Accuracy: 0.9545
# [translation_16px] Avg Accuracy: 0.9475
# [translation_32px] Avg Accuracy: 0.9350
# [Cue Conflict] Shape Bias: 26.36%, Coverage: 64.50%
#
# --- Running Interventions on vit_b_16 ---
# Quickly reloading linear head weights...
# [grayscale] Accuracy: 0.9400
# [hue_rotation] Accuracy: 0.9360
# [patch_shuffle] Accuracy: 0.9180
# [translation_8px] Avg Accuracy: 0.9725
# [translation_16px] Avg Accuracy: 0.9730
# [translation_32px] Avg Accuracy: 0.9680
# [Cue Conflict] Shape Bias: 38.61%, Coverage: 79.00%
#
# --- Running Interventions on clip_vit_b_32 ---
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# Quickly reloading linear head weights...
# [grayscale] Accuracy: 0.9240
# [hue_rotation] Accuracy: 0.9300
# [patch_shuffle] Accuracy: 0.7760
# [translation_8px] Avg Accuracy: 0.9585
# [translation_16px] Avg Accuracy: 0.9580
# [translation_32px] Avg Accuracy: 0.9410
# [Cue Conflict] Shape Bias: 46.94%, Coverage: 49.00%
#
# Saved all bias results to /content/ATML-PA1/task1/results/bias_results.json

# %%
# !python -m task1.analysis.plot_translation
# Out:
# Translation accuracy curve saved to task1/results/translation_curve_accuracy.png

# %%
# !python -m task1.analysis.run_representation_analysis
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# /usr/local/lib/python3.13/dist-packages/open_clip/factory.py:450: UserWarning: QuickGELU mismatch between final model config (quick_gelu=False) and pretrained tag 'openai' (quick_gelu=True).
#   warnings.warn(
# Extracting clean features...
# Running intervention analysis...
# --- Intervention: Grayscale ---
# ResNet-50 Cosine Stability: 0.7981
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ResNet-50_Grayscale.png
# ViT-B/16 Cosine Stability: 0.7316
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ViT-B16_Grayscale.png
# OpenCLIP Cosine Stability: 0.8850
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_OpenCLIP_Grayscale.png
# --- Intervention: Patch Shuffle ---
# ResNet-50 Cosine Stability: 0.6982
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ResNet-50_PatchShuffle.png
# ViT-B/16 Cosine Stability: 0.6143
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ViT-B16_PatchShuffle.png
# OpenCLIP Cosine Stability: 0.7452
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_OpenCLIP_PatchShuffle.png
# --- Intervention: Translation ---
# ResNet-50 Cosine Stability: 0.9592
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ResNet-50_Translation.png
# ViT-B/16 Cosine Stability: 0.9778
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_ViT-B16_Translation.png
# OpenCLIP Cosine Stability: 0.9622
# /content/ATML-PA1/task1/analysis/run_representation_analysis.py:88: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap('tab10', len(unique_classes))
# Saved plot to task1/results/tsne_OpenCLIP_Translation.png

# %%
# !zip -r /content/task1_results.zip /content/ATML-PA1/task1/results
from google.colab import files
files.download("/content/task1_results.zip")
# Out:
#   adding: content/ATML-PA1/task1/results/ (stored 0%)
#   adding: content/ATML-PA1/task1/results/tsne_ResNet-50_Translation.png (deflated 6%)
#   adding: content/ATML-PA1/task1/results/translation_curve_accuracy.png (deflated 15%)
#   adding: content/ATML-PA1/task1/results/tsne_OpenCLIP_PatchShuffle.png (deflated 3%)
#   adding: content/ATML-PA1/task1/results/clean_baseline.json (deflated 56%)
#   adding: content/ATML-PA1/task1/results/tsne_OpenCLIP_Translation.png (deflated 5%)
#   adding: content/ATML-PA1/task1/results/tsne_ResNet-50_PatchShuffle.png (deflated 4%)
#   adding: content/ATML-PA1/task1/results/tsne_ViT-B16_Translation.png (deflated 6%)
#   adding: content/ATML-PA1/task1/results/bias_results.json (deflated 69%)
#   adding: content/ATML-PA1/task1/results/tsne_ResNet-50_Grayscale.png (deflated 4%)
#   adding: content/ATML-PA1/task1/results/tsne_ViT-B16_Grayscale.png (deflated 3%)
#   adding: content/ATML-PA1/task1/results/tsne_ViT-B16_PatchShuffle.png (deflated 4%)
#   adding: content/ATML-PA1/task1/results/tsne_OpenCLIP_Grayscale.png (deflated 4%)

# %%
# !python -m shared.pacs_protocol
# Out:
# Downloading PACS dataset via GitHub mirror...
# Cloning into 'data_cache/PACS/temp_repo'...
# remote: Enumerating objects: 10032, done.
# remote: Total 10032 (delta 0), reused 0 (delta 0), pack-reused 10032 (from 1)
# Receiving objects: 100% (10032/10032), 174.13 MiB | 31.51 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (9993/9993), done.
# Download complete!
# Splits saved to shared/splits/pacs_sketch_seed6304.json

# %%
# !python -m task2.train --method source_only
# !python -m task2.train --method dan
# !python -m task2.train --method dann
# !python -m task2.train --method cdan
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 167MB/s]
# Epoch   1 | cls_loss=0.5310 | align_loss=0.0000 | mean_src_F1=0.9015 | mean_src_Acc=0.9015
#        photo          : F1=0.9540  Acc=0.9581
#        art_painting   : F1=0.8436  Acc=0.8488
#        cartoon        : F1=0.9070  Acc=0.8977
#   -> Saved best checkpoint (F1=0.9015)
# Epoch   2 | cls_loss=0.2527 | align_loss=0.0000 | mean_src_F1=0.8968 | mean_src_Acc=0.9019
#        photo          : F1=0.9390  Acc=0.9491
#        art_painting   : F1=0.8342  Acc=0.8439
#        cartoon        : F1=0.9172  Acc=0.9126
# Epoch   3 | cls_loss=0.1966 | align_loss=0.0000 | mean_src_F1=0.9332 | mean_src_Acc=0.9336
#        photo          : F1=0.9616  Acc=0.9671
#        art_painting   : F1=0.8957  Acc=0.8976
#        cartoon        : F1=0.9424  Acc=0.9360
#   -> Saved best checkpoint (F1=0.9332)
# Epoch   4 | cls_loss=0.1402 | align_loss=0.0000 | mean_src_F1=0.9167 | mean_src_Acc=0.9158
#        photo          : F1=0.9439  Acc=0.9521
#        art_painting   : F1=0.8837  Acc=0.8805
#        cartoon        : F1=0.9224  Acc=0.9147
# Epoch   5 | cls_loss=0.1079 | align_loss=0.0000 | mean_src_F1=0.9226 | mean_src_Acc=0.9247
#        photo          : F1=0.9442  Acc=0.9551
#        art_painting   : F1=0.8811  Acc=0.8829
#        cartoon        : F1=0.9425  Acc=0.9360
# Epoch   6 | cls_loss=0.0978 | align_loss=0.0000 | mean_src_F1=0.9200 | mean_src_Acc=0.9222
#        photo          : F1=0.9417  Acc=0.9521
#        art_painting   : F1=0.8822  Acc=0.8805
#        cartoon        : F1=0.9361  Acc=0.9339
# Epoch   7 | cls_loss=0.1058 | align_loss=0.0000 | mean_src_F1=0.9234 | mean_src_Acc=0.9221
#        photo          : F1=0.9533  Acc=0.9581
#        art_painting   : F1=0.8855  Acc=0.8829
#        cartoon        : F1=0.9316  Acc=0.9254
# Epoch   8 | cls_loss=0.0975 | align_loss=0.0000 | mean_src_F1=0.9270 | mean_src_Acc=0.9288
#        photo          : F1=0.9380  Acc=0.9461
#        art_painting   : F1=0.8965  Acc=0.9000
#        cartoon        : F1=0.9466  Acc=0.9403
# Early stopping triggered at epoch 8
# Training history saved to task2/results/source_only_history.json
# Using device: cuda
# Epoch   1 | cls_loss=0.7782 | align_loss=0.2281 | mean_src_F1=0.9174 | mean_src_Acc=0.9189
#        photo          : F1=0.9464  Acc=0.9551
#        art_painting   : F1=0.8918  Acc=0.8976
#        cartoon        : F1=0.9139  Acc=0.9041
#   -> Saved best checkpoint (F1=0.9174)
# Epoch   2 | cls_loss=0.4462 | align_loss=0.1915 | mean_src_F1=0.9251 | mean_src_Acc=0.9261
#        photo          : F1=0.9416  Acc=0.9521
#        art_painting   : F1=0.9083  Acc=0.9073
#        cartoon        : F1=0.9253  Acc=0.9190
#   -> Saved best checkpoint (F1=0.9251)
# Epoch   3 | cls_loss=0.3613 | align_loss=0.1793 | mean_src_F1=0.9171 | mean_src_Acc=0.9159
#        photo          : F1=0.9609  Acc=0.9671
#        art_painting   : F1=0.8679  Acc=0.8659
#        cartoon        : F1=0.9224  Acc=0.9147
# Epoch   4 | cls_loss=0.3070 | align_loss=0.1728 | mean_src_F1=0.9300 | mean_src_Acc=0.9290
#        photo          : F1=0.9752  Acc=0.9790
#        art_painting   : F1=0.8810  Acc=0.8805
#        cartoon        : F1=0.9337  Acc=0.9275
#   -> Saved best checkpoint (F1=0.9300)
# Epoch   5 | cls_loss=0.2777 | align_loss=0.1709 | mean_src_F1=0.9422 | mean_src_Acc=0.9425
#        photo          : F1=0.9725  Acc=0.9760
#        art_painting   : F1=0.9032  Acc=0.9049
#        cartoon        : F1=0.9508  Acc=0.9467
#   -> Saved best checkpoint (F1=0.9422)
# Epoch   6 | cls_loss=0.2705 | align_loss=0.1767 | mean_src_F1=0.9395 | mean_src_Acc=0.9379
#        photo          : F1=0.9603  Acc=0.9671
#        art_painting   : F1=0.9076  Acc=0.9000
#        cartoon        : F1=0.9505  Acc=0.9467
# Epoch   7 | cls_loss=0.2479 | align_loss=0.1671 | mean_src_F1=0.9169 | mean_src_Acc=0.9194
#        photo          : F1=0.9600  Acc=0.9671
#        art_painting   : F1=0.8638  Acc=0.8659
#        cartoon        : F1=0.9268  Acc=0.9254
# Epoch   8 | cls_loss=0.2544 | align_loss=0.1691 | mean_src_F1=0.9321 | mean_src_Acc=0.9324
#        photo          : F1=0.9534  Acc=0.9611
#        art_painting   : F1=0.9017  Acc=0.9000
#        cartoon        : F1=0.9413  Acc=0.9360
# Epoch   9 | cls_loss=0.2398 | align_loss=0.1674 | mean_src_F1=0.9142 | mean_src_Acc=0.9164
#        photo          : F1=0.9480  Acc=0.9551
#        art_painting   : F1=0.8713  Acc=0.8707
#        cartoon        : F1=0.9234  Acc=0.9232
# Epoch  10 | cls_loss=0.2455 | align_loss=0.1594 | mean_src_F1=0.9231 | mean_src_Acc=0.9242
#        photo          : F1=0.9538  Acc=0.9611
#        art_painting   : F1=0.8752  Acc=0.8756
#        cartoon        : F1=0.9403  Acc=0.9360
# Early stopping triggered at epoch 10
# Training history saved to task2/results/dan_history.json
# Using device: cuda
# Epoch   1 | cls_loss=6082.2784 | align_loss=5575.8347 | mean_src_F1=0.0331 | mean_src_Acc=0.1313
#        photo          : F1=0.0278  Acc=0.1078
#        art_painting   : F1=0.0349  Acc=0.1390
#        cartoon        : F1=0.0366  Acc=0.1471
#   -> Saved best checkpoint (F1=0.0331)
# Epoch   2 | cls_loss=139.7214 | align_loss=91.1350 | mean_src_F1=0.0226 | mean_src_Acc=0.0862
#        photo          : F1=0.0285  Acc=0.1108
#        art_painting   : F1=0.0236  Acc=0.0902
#        cartoon        : F1=0.0156  Acc=0.0576
# Epoch   3 | cls_loss=235.2956 | align_loss=177.1490 | mean_src_F1=0.1037 | mean_src_Acc=0.2047
#        photo          : F1=0.1057  Acc=0.2246
#        art_painting   : F1=0.0844  Acc=0.1805
#        cartoon        : F1=0.1211  Acc=0.2090
#   -> Saved best checkpoint (F1=0.1037)
# Epoch   4 | cls_loss=159.9025 | align_loss=108.7125 | mean_src_F1=0.0763 | mean_src_Acc=0.1289
#        photo          : F1=0.0726  Acc=0.1078
#        art_painting   : F1=0.0618  Acc=0.1146
#        cartoon        : F1=0.0947  Acc=0.1642
# Epoch   5 | cls_loss=2437.7258 | align_loss=1518.9486 | mean_src_F1=0.0331 | mean_src_Acc=0.1313
#        photo          : F1=0.0278  Acc=0.1078
#        art_painting   : F1=0.0349  Acc=0.1390
#        cartoon        : F1=0.0366  Acc=0.1471
# Epoch   6 | cls_loss=6554.2334 | align_loss=3483.0865 | mean_src_F1=0.0723 | mean_src_Acc=0.1102
#        photo          : F1=0.0958  Acc=0.1108
#        art_painting   : F1=0.0616  Acc=0.1024
#        cartoon        : F1=0.0596  Acc=0.1173
# Epoch   7 | cls_loss=37790.9273 | align_loss=17979.2493 | mean_src_F1=0.0507 | mean_src_Acc=0.2166
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Epoch   8 | cls_loss=21.0512 | align_loss=12.2769 | mean_src_F1=0.0361 | mean_src_Acc=0.1451
#        photo          : F1=0.0410  Acc=0.1677
#        art_painting   : F1=0.0359  Acc=0.1439
#        cartoon        : F1=0.0314  Acc=0.1237
# Early stopping triggered at epoch 8
# Training history saved to task2/results/dann_history.json
# Using device: cuda
# Epoch   1 | cls_loss=1.2276 | align_loss=0.6470 | mean_src_F1=0.6941 | mean_src_Acc=0.6902
#        photo          : F1=0.7416  Acc=0.7455
#        art_painting   : F1=0.7225  Acc=0.7366
#        cartoon        : F1=0.6183  Acc=0.5885
#   -> Saved best checkpoint (F1=0.6941)
# Epoch   2 | cls_loss=36493.3182 | align_loss=33152.8679 | mean_src_F1=0.0551 | mean_src_Acc=0.2140
#        photo          : F1=0.0667  Acc=0.2605
#        art_painting   : F1=0.0521  Acc=0.2195
#        cartoon        : F1=0.0466  Acc=0.1620
# Epoch   3 | cls_loss=2.7174 | align_loss=0.6888 | mean_src_F1=0.0618 | mean_src_Acc=0.2105
#        photo          : F1=0.0748  Acc=0.2635
#        art_painting   : F1=0.0598  Acc=0.2146
#        cartoon        : F1=0.0508  Acc=0.1535
# Epoch   4 | cls_loss=2.6227 | align_loss=0.6524 | mean_src_F1=0.0382 | mean_src_Acc=0.1551
#        photo          : F1=0.0292  Acc=0.1138
#        art_painting   : F1=0.0447  Acc=0.1854
#        cartoon        : F1=0.0407  Acc=0.1663
# Epoch   5 | cls_loss=2.6400 | align_loss=0.6458 | mean_src_F1=0.0909 | mean_src_Acc=0.2220
#        photo          : F1=0.1159  Acc=0.2934
#        art_painting   : F1=0.0840  Acc=0.2000
#        cartoon        : F1=0.0728  Acc=0.1727
# Epoch   6 | cls_loss=2.6290 | align_loss=0.6652 | mean_src_F1=0.1211 | mean_src_Acc=0.1997
#        photo          : F1=0.1423  Acc=0.2425
#        art_painting   : F1=0.1118  Acc=0.1732
#        cartoon        : F1=0.1090  Acc=0.1834
# Early stopping triggered at epoch 6
# Training history saved to task2/results/cdan_history.json

# %%
# !python -m task2.evaluate_final
# Out:
# ============================================================
#   Evaluating SOURCE_ONLY
# ============================================================
#   photo           val — Acc: 0.9671  Macro-F1: 0.9616
#   art_painting    val — Acc: 0.8976  Macro-F1: 0.8957
#   cartoon         val — Acc: 0.9360  Macro-F1: 0.9424
#   MEAN SOURCE     val — Acc: 0.9336  Macro-F1: 0.9332
#
#   Target (Sketch) — Acc: 0.6686  Macro-F1: 0.7109
#   Domain separability (LR acc, 70/30, C=1): 1.0000  (chance=0.50)
# 2026-09-25 04:34:40.363455: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_source_only.png
#
# ============================================================
#   Evaluating DAN
# ============================================================
#   photo           val — Acc: 0.9760  Macro-F1: 0.9725
#   art_painting    val — Acc: 0.9049  Macro-F1: 0.9032
#   cartoon         val — Acc: 0.9467  Macro-F1: 0.9508
#   MEAN SOURCE     val — Acc: 0.9425  Macro-F1: 0.9422
#
#   Target (Sketch) — Acc: 0.5337  Macro-F1: 0.5047
#   Domain separability (LR acc, 70/30, C=1): 0.8503  (chance=0.50)
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_dan.png
#
# ============================================================
#   Evaluating DANN
# ============================================================
#   photo           val — Acc: 0.2246  Macro-F1: 0.1057
#   art_painting    val — Acc: 0.1805  Macro-F1: 0.0844
#   cartoon         val — Acc: 0.2090  Macro-F1: 0.1211
#   MEAN SOURCE     val — Acc: 0.2047  Macro-F1: 0.1037
#
#   Target (Sketch) — Acc: 0.0512  Macro-F1: 0.0245
#   Domain separability (LR acc, 70/30, C=1): 0.9959  (chance=0.50)
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_dann.png
#
# ============================================================
#   Evaluating CDAN
# ============================================================
#   photo           val — Acc: 0.7455  Macro-F1: 0.7416
#   art_painting    val — Acc: 0.7366  Macro-F1: 0.7225
#   cartoon         val — Acc: 0.5885  Macro-F1: 0.6183
#   MEAN SOURCE     val — Acc: 0.6902  Macro-F1: 0.6941
#
#   Target (Sketch) — Acc: 0.2265  Macro-F1: 0.1581
#   Domain separability (LR acc, 70/30, C=1): 1.0000  (chance=0.50)
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_cdan.png
#
# Class           |   src_only |        dan |       dann |       cdan
# ----------------------------------------------------------------------
# dog             |     0.3795 |    -0.0155 |    -0.3238 |    +0.6205
# elephant        |     0.5122 |    +0.2432 |    -0.5122 |    -0.5122
# giraffe         |     0.5219 |    -0.1248 |    -0.5219 |    -0.4648
# guitar          |     0.9194 |    -0.2977 |    -0.9194 |    -0.8421
# horse           |     0.9632 |    -0.3873 |    -0.9608 |    -0.9632
# house           |     0.9125 |    +0.0875 |    -0.9125 |    -0.5625
# person          |     0.9000 |    -0.7125 |    +0.0750 |    -0.9000
#
# ================================================================================
# SUMMARY TABLE
# Method       |  Tgt Acc |   Tgt F1 |    Tgt Δ |  Dom Sep |  Src Acc
# ----------------------------------------------------------------------
# source_only  |   0.6686 |   0.7109 |  +0.0000 |   1.0000 |   0.9336
# dan          |   0.5337 |   0.5047 |  -0.1349 |   0.8503 |   0.9425
# dann         |   0.0512 |   0.0245 |  -0.6175 |   0.9959 |   0.2047
# cdan         |   0.2265 |   0.1581 |  -0.4421 |   1.0000 |   0.6902
#
# All metrics saved to task2/results/final_eval.json
# Training curves saved to task2/results/training_curves.png

# %%
# !python -m task2.controlled_study
# Out:
# Device: cuda
#
# Expectations:
#   lambda=0.1 (weak): low MMD pressure → src perf stable, dom_sep high, tgt ~ source_only
#   lambda=1.0 (main): moderate alignment → see main comparison results
#   lambda=10  (strong): heavy MMD → may hurt class structure, dom_sep lower, tgt may drop
#
# --- DAN lambda_mmd = 0.1 ---
#   Epoch   1 | cls=0.5177 mmd=0.0353 src_f1=0.8985
#   Epoch   2 | cls=0.2464 mmd=0.0263 src_f1=0.8994
#   Epoch   3 | cls=0.1772 mmd=0.0233 src_f1=0.9071
#   Epoch   4 | cls=0.1458 mmd=0.0226 src_f1=0.9202
#   Epoch   5 | cls=0.1286 mmd=0.0221 src_f1=0.9268
#   Epoch   6 | cls=0.0929 mmd=0.0218 src_f1=0.9416
#   Epoch   7 | cls=0.0992 mmd=0.0215 src_f1=0.9320
#   Epoch   8 | cls=0.0501 mmd=0.0208 src_f1=0.9438
#   Epoch   9 | cls=0.0671 mmd=0.0203 src_f1=0.9115
#   Epoch  10 | cls=0.0547 mmd=0.0195 src_f1=0.9333
#   Epoch  11 | cls=0.0476 mmd=0.0200 src_f1=0.9266
#   Epoch  12 | cls=0.0386 mmd=0.0198 src_f1=0.9467
#   Epoch  13 | cls=0.0816 mmd=0.0203 src_f1=0.9196
#   Epoch  14 | cls=0.0481 mmd=0.0198 src_f1=0.9293
#   Epoch  15 | cls=0.0369 mmd=0.0191 src_f1=0.9521
#   Epoch  16 | cls=0.0395 mmd=0.0192 src_f1=0.9328
#   Epoch  17 | cls=0.0340 mmd=0.0193 src_f1=0.9379
#   Epoch  18 | cls=0.0331 mmd=0.0190 src_f1=0.9342
#   Epoch  19 | cls=0.0320 mmd=0.0193 src_f1=0.9207
#   Epoch  20 | cls=0.0543 mmd=0.0190 src_f1=0.9389
#   Early stopping at epoch 20
#
# --- DAN lambda_mmd = 1.0 ---
#   Epoch   1 | cls=0.5557 mmd=0.2281 src_f1=0.9200
#   Epoch   2 | cls=0.2580 mmd=0.1888 src_f1=0.9302
#   Epoch   3 | cls=0.1754 mmd=0.1805 src_f1=0.9211
#   Epoch   4 | cls=0.1239 mmd=0.1735 src_f1=0.9134
#   Epoch   5 | cls=0.1143 mmd=0.1758 src_f1=0.9304
#   Epoch   6 | cls=0.1053 mmd=0.1783 src_f1=0.9385
#   Epoch   7 | cls=0.0722 mmd=0.1677 src_f1=0.9296
#   Epoch   8 | cls=0.0773 mmd=0.1681 src_f1=0.9411
#   Epoch   9 | cls=0.0659 mmd=0.1671 src_f1=0.9267
#   Epoch  10 | cls=0.0775 mmd=0.1595 src_f1=0.9259
#   Epoch  11 | cls=0.0691 mmd=0.1689 src_f1=0.9255
#   Epoch  12 | cls=0.0606 mmd=0.1648 src_f1=0.9302
#   Epoch  13 | cls=0.0663 mmd=0.1669 src_f1=0.9275
#   Early stopping at epoch 13
#
# --- DAN lambda_mmd = 10.0 ---
#   Epoch   1 | cls=1.9458 mmd=2.2517 src_f1=0.0507
#   Epoch   2 | cls=1.9415 mmd=2.2673 src_f1=0.0507
#   Epoch   3 | cls=1.9410 mmd=2.0003 src_f1=0.0507
#   Epoch   4 | cls=1.9391 mmd=2.1153 src_f1=0.0507
#   Epoch   5 | cls=1.9377 mmd=1.7441 src_f1=0.0507
#   Epoch   6 | cls=1.9365 mmd=1.9980 src_f1=0.0507
#   Early stopping at epoch 6
#
#   lambda_mmd |  Src Acc |  Tgt Acc |   Tgt F1 |  Dom Sep
# ------------------------------------------------------------
#          0.1 |   0.9525 |   0.6941 |   0.6334 |   0.9519
#          1.0 |   0.9421 |   0.6037 |   0.5564 |   0.8269
#         10.0 |   0.2166 |   0.0407 |   0.0112 |   0.7239
#
# Plot saved to task2/results/controlled_study_dan.png
# Results saved to task2/results/controlled_study_dan.json
