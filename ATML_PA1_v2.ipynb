# %%
# !git clone https://github.com/syedmoazzamrazagilani/ATML-PA1.git
# Out:
# Cloning into 'ATML-PA1'...
# remote: Enumerating objects: 234, done.
# remote: Counting objects: 100% (234/234), done.
# remote: Compressing objects: 100% (212/212), done.
# remote: Total 234 (delta 94), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (234/234), 83.24 KiB | 3.62 MiB/s, done.
# Resolving deltas: 100% (94/94), done.

# %%
# %cd ATML-PA1
# Out:
# /content/ATML-PA1

# %%
# !python -m shared.pacs_protocol
# Out:
# Downloading PACS dataset via GitHub mirror...
# Cloning into 'data_cache/PACS/temp_repo'...
# remote: Enumerating objects: 10032, done.
# remote: Total 10032 (delta 0), reused 0 (delta 0), pack-reused 10032 (from 1)
# Receiving objects: 100% (10032/10032), 174.13 MiB | 19.35 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# Updating files: 100% (9993/9993), done.
# Download complete!
# Splits saved to shared/splits/pacs_sketch_seed6304.json

# %%
# !python -m task2.train --method dann
# !python -m task2.train --method cdan
# Out:
# [dann] Using device: cuda
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 227MB/s]
# Epoch   1 | cls=1.0328  align=0.4669  src_F1=0.8199  src_Acc=0.8328
#        photo          : F1=0.8991  Acc=0.9132
#        art_painting   : F1=0.7235  Acc=0.7366
#        cartoon        : F1=0.8372  Acc=0.8486
#   -> Saved best checkpoint (F1=0.8199)
# Epoch   2 | cls=0.9321  align=0.6336  src_F1=0.8477  src_Acc=0.8513
#        photo          : F1=0.9049  Acc=0.9222
#        art_painting   : F1=0.7789  Acc=0.7854
#        cartoon        : F1=0.8593  Acc=0.8465
#   -> Saved best checkpoint (F1=0.8477)
# Epoch   3 | cls=0.9260  align=0.6604  src_F1=0.8650  src_Acc=0.8680
#        photo          : F1=0.9185  Acc=0.9311
#        art_painting   : F1=0.7875  Acc=0.7902
#        cartoon        : F1=0.8890  Acc=0.8827
#   -> Saved best checkpoint (F1=0.8650)
# Epoch   4 | cls=0.8818  align=0.6838  src_F1=0.9387  src_Acc=0.9396
#        photo          : F1=0.9607  Acc=0.9671
#        art_painting   : F1=0.9058  Acc=0.9073
#        cartoon        : F1=0.9495  Acc=0.9446
#   -> Saved best checkpoint (F1=0.9387)
# Epoch   5 | cls=0.8434  align=0.6896  src_F1=0.9100  src_Acc=0.9085
#        photo          : F1=0.9365  Acc=0.9461
#        art_painting   : F1=0.8772  Acc=0.8732
#        cartoon        : F1=0.9163  Acc=0.9062
# Epoch   6 | cls=1.0673  align=0.8445  src_F1=0.9212  src_Acc=0.9191
#        photo          : F1=0.9448  Acc=0.9491
#        art_painting   : F1=0.9006  Acc=0.9000
#        cartoon        : F1=0.9181  Acc=0.9083
# Epoch   7 | cls=0.8701  align=0.7170  src_F1=0.9078  src_Acc=0.9019
#        photo          : F1=0.9441  Acc=0.9521
#        art_painting   : F1=0.8503  Acc=0.8390
#        cartoon        : F1=0.9289  Acc=0.9147
# Epoch   8 | cls=1.0093  align=0.7830  src_F1=0.9301  src_Acc=0.9302
#        photo          : F1=0.9508  Acc=0.9581
#        art_painting   : F1=0.8882  Acc=0.8878
#        cartoon        : F1=0.9514  Acc=0.9446
# Epoch   9 | cls=0.8757  align=0.7396  src_F1=0.9317  src_Acc=0.9302
#        photo          : F1=0.9603  Acc=0.9671
#        art_painting   : F1=0.8888  Acc=0.8854
#        cartoon        : F1=0.9460  Acc=0.9382
# Early stopping at epoch 9
# History saved → task2/results/dann_history.json
# [cdan] Using device: cuda
# Epoch   1 | cls=1.3635  align=0.7620  src_F1=0.8720  src_Acc=0.8726
#        photo          : F1=0.9360  Acc=0.9461
#        art_painting   : F1=0.8216  Acc=0.8317
#        cartoon        : F1=0.8582  Acc=0.8401
#   -> Saved best checkpoint (F1=0.8720)
# Epoch   2 | cls=0.9372  align=0.5919  src_F1=0.8797  src_Acc=0.8802
#        photo          : F1=0.9492  Acc=0.9581
#        art_painting   : F1=0.7987  Acc=0.7976
#        cartoon        : F1=0.8912  Acc=0.8849
#   -> Saved best checkpoint (F1=0.8797)
# Epoch   3 | cls=0.9025  align=0.6629  src_F1=0.8778  src_Acc=0.8755
#        photo          : F1=0.9566  Acc=0.9611
#        art_painting   : F1=0.7835  Acc=0.7805
#        cartoon        : F1=0.8932  Acc=0.8849
# Epoch   4 | cls=0.9148  align=0.6870  src_F1=0.8902  src_Acc=0.8968
#        photo          : F1=0.9150  Acc=0.9281
#        art_painting   : F1=0.8448  Acc=0.8561
#        cartoon        : F1=0.9109  Acc=0.9062
#   -> Saved best checkpoint (F1=0.8902)
# Epoch   5 | cls=0.8571  align=0.6944  src_F1=0.9042  src_Acc=0.9059
#        photo          : F1=0.9251  Acc=0.9341
#        art_painting   : F1=0.8524  Acc=0.8561
#        cartoon        : F1=0.9351  Acc=0.9275
#   -> Saved best checkpoint (F1=0.9042)
# Epoch   6 | cls=0.8512  align=0.6882  src_F1=0.8959  src_Acc=0.8975
#        photo          : F1=0.9399  Acc=0.9461
#        art_painting   : F1=0.8427  Acc=0.8488
#        cartoon        : F1=0.9051  Acc=0.8977
# Epoch   7 | cls=0.8277  align=0.6925  src_F1=0.9155  src_Acc=0.9167
#        photo          : F1=0.9511  Acc=0.9581
#        art_painting   : F1=0.8531  Acc=0.8561
#        cartoon        : F1=0.9422  Acc=0.9360
#   -> Saved best checkpoint (F1=0.9155)
# Epoch   8 | cls=0.7947  align=0.6915  src_F1=0.9323  src_Acc=0.9321
#        photo          : F1=0.9615  Acc=0.9671
#        art_painting   : F1=0.8979  Acc=0.8976
#        cartoon        : F1=0.9376  Acc=0.9318
#   -> Saved best checkpoint (F1=0.9323)
# Epoch   9 | cls=0.8113  align=0.6938  src_F1=0.9077  src_Acc=0.9093
#        photo          : F1=0.9385  Acc=0.9461
#        art_painting   : F1=0.8558  Acc=0.8585
#        cartoon        : F1=0.9289  Acc=0.9232
# Epoch  10 | cls=0.7627  align=0.6942  src_F1=0.9419  src_Acc=0.9434
#        photo          : F1=0.9743  Acc=0.9790
#        art_painting   : F1=0.8995  Acc=0.9024
#        cartoon        : F1=0.9521  Acc=0.9488
#   -> Saved best checkpoint (F1=0.9419)
# Epoch  11 | cls=0.7563  align=0.6926  src_F1=0.9068  src_Acc=0.9096
#        photo          : F1=0.9266  Acc=0.9371
#        art_painting   : F1=0.8645  Acc=0.8683
#        cartoon        : F1=0.9294  Acc=0.9232
# Epoch  12 | cls=0.7784  align=0.6910  src_F1=0.8816  src_Acc=0.8895
#        photo          : F1=0.9044  Acc=0.9222
#        art_painting   : F1=0.8377  Acc=0.8488
#        cartoon        : F1=0.9026  Acc=0.8977
# Epoch  13 | cls=0.7657  align=0.6961  src_F1=0.9066  src_Acc=0.9070
#        photo          : F1=0.9327  Acc=0.9401
#        art_painting   : F1=0.8666  Acc=0.8683
#        cartoon        : F1=0.9204  Acc=0.9126
# Epoch  14 | cls=0.8683  align=0.7385  src_F1=0.8961  src_Acc=0.8965
#        photo          : F1=0.9289  Acc=0.9371
#        art_painting   : F1=0.8626  Acc=0.8610
#        cartoon        : F1=0.8968  Acc=0.8913
# Epoch  15 | cls=1.5560  align=0.9934  src_F1=0.9102  src_Acc=0.9152
#        photo          : F1=0.9265  Acc=0.9371
#        art_painting   : F1=0.8594  Acc=0.8683
#        cartoon        : F1=0.9447  Acc=0.9403
# Early stopping at epoch 15
# History saved → task2/results/cdan_history.json

# %%
# !python -m task2.evaluate_final
# Out:
# [SKIP] source_only: no checkpoint at task2/checkpoints/source_only_best.pth
# [SKIP] dan: no checkpoint at task2/checkpoints/dan_best.pth
#
# ============================================================
#   Evaluating DANN
# ============================================================
#   photo           val — Acc: 0.9671  Macro-F1: 0.9607
#   art_painting    val — Acc: 0.9073  Macro-F1: 0.9058
#   cartoon         val — Acc: 0.9446  Macro-F1: 0.9495
#   MEAN SOURCE     val — Acc: 0.9396  Macro-F1: 0.9387
#
#   Target (Sketch) — Acc: 0.7050  Macro-F1: 0.6599
#   Domain separability (LR acc, 70/30, C=1): 0.9725  (chance=0.50)
# 2026-09-25 06:16:07.842798: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_dann.png
#
# ============================================================
#   Evaluating CDAN
# ============================================================
#   photo           val — Acc: 0.9790  Macro-F1: 0.9743
#   art_painting    val — Acc: 0.9024  Macro-F1: 0.8995
#   cartoon         val — Acc: 0.9488  Macro-F1: 0.9521
#   MEAN SOURCE     val — Acc: 0.9434  Macro-F1: 0.9419
#
#   Target (Sketch) — Acc: 0.7524  Macro-F1: 0.7004
#   Domain separability (LR acc, 70/30, C=1): 0.9780  (chance=0.50)
# /usr/local/lib/python3.13/dist-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# UMAP plot saved to task2/results/umap_cdan.png
#
# ================================================================================
# SUMMARY TABLE
# Method       |  Tgt Acc |   Tgt F1 |    Tgt Δ |  Dom Sep |  Src Acc
# ----------------------------------------------------------------------
# dann         |   0.7050 |   0.6599 |  +0.0000 |   0.9725 |   0.9396
# cdan         |   0.7524 |   0.7004 |  +0.0000 |   0.9780 |   0.9434
#
# All metrics saved to task2/results/final_eval.json
# Training curves saved to task2/results/training_curves.png

# %%
# !git pull
# Out:
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 5 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.21 KiB | 1.21 MiB/s, done.
# From https://github.com/syedmoazzamrazagilani/ATML-PA1
#    9e47e72..0775f43  main       -> origin/main
# Updating 9e47e72..0775f43
# Fast-forward
#  task3/methods/erm.py | 13 +++++++++++++
#  1 file changed, 13 insertions(+)
#  create mode 100644 task3/methods/erm.py

# %%
# !python -m task3.train --method erm
# Out:
# ERM checkpoint copied: task2/checkpoints/source_only_best.pth -> task3/checkpoints/erm_best.pth
#
# ERM source-validation metrics:
#   photo: {'acc': 0.9700598802395209, 'f1': 0.9641749668020979}
#   art_painting: {'acc': 0.9073170731707317, 'f1': 0.9063770829413709}
#   cartoon: {'acc': 0.9509594882729211, 'f1': 0.954164500524712}
#   mean_acc: 0.9427788138943912
#   mean_f1: 0.941572183422727
#   worst_acc: 0.9073170731707317
#   worst_f1: 0.9063770829413709
# ERM history saved.

# %%
# !python -m task3.train --method dan_dg
# Out:
# [DAN-DG] device=cuda  lambda_dg=1.0
# Epoch   1 | cls=1.9356  mmd=0.5696 | mean_F1=0.0361  worst_F1=0.0314
#        photo          : F1=0.0410  Acc=0.1677
#        art_painting   : F1=0.0359  Acc=0.1439
#        cartoon        : F1=0.0314  Acc=0.1237
#   -> Checkpoint saved (F1=0.0361)
# Epoch   2 | cls=1.9393  mmd=0.5048 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
#   -> Checkpoint saved (F1=0.0507)
# Epoch   3 | cls=1.9373  mmd=0.4292 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Epoch   4 | cls=1.9358  mmd=0.2365 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Epoch   5 | cls=1.9350  mmd=0.4812 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Epoch   6 | cls=1.9362  mmd=0.5009 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Epoch   7 | cls=1.9309  mmd=0.4278 | mean_F1=0.0507  worst_F1=0.0421
#        photo          : F1=0.0585  Acc=0.2575
#        art_painting   : F1=0.0514  Acc=0.2195
#        cartoon        : F1=0.0421  Acc=0.1727
# Early stopping at epoch 7
# DAN-DG history saved.

# %%
# !python -m task3.train --method sam
# Out:
# [SAM] device=cuda  rho=0.05
# Epoch   1 | loss_asc=0.8240  loss_desc=1.1750 | mean_F1=0.8860  worst_F1=0.8229
#        photo          : F1=0.9427  Acc=0.9521
#        art_painting   : F1=0.8229  Acc=0.8268
#        cartoon        : F1=0.8924  Acc=0.8913
#   -> Checkpoint saved (F1=0.8860)
# Epoch   2 | loss_asc=0.3005  loss_desc=0.5972 | mean_F1=0.8795  worst_F1=0.8556
#        photo          : F1=0.9271  Acc=0.9371
#        art_painting   : F1=0.8556  Acc=0.8610
#        cartoon        : F1=0.8558  Acc=0.8550
# Epoch   3 | loss_asc=0.2121  loss_desc=0.4697 | mean_F1=0.9171  worst_F1=0.8650
#        photo          : F1=0.9590  Acc=0.9641
#        art_painting   : F1=0.8650  Acc=0.8585
#        cartoon        : F1=0.9274  Acc=0.9254
#   -> Checkpoint saved (F1=0.9171)
# Epoch   4 | loss_asc=0.1796  loss_desc=0.4115 | mean_F1=0.9271  worst_F1=0.8812
#        photo          : F1=0.9574  Acc=0.9641
#        art_painting   : F1=0.8812  Acc=0.8756
#        cartoon        : F1=0.9427  Acc=0.9339
#   -> Checkpoint saved (F1=0.9271)
# Epoch   5 | loss_asc=0.1193  loss_desc=0.3067 | mean_F1=0.9414  worst_F1=0.9158
#        photo          : F1=0.9551  Acc=0.9611
#        art_painting   : F1=0.9158  Acc=0.9171
#        cartoon        : F1=0.9534  Acc=0.9467
#   -> Checkpoint saved (F1=0.9414)
# Epoch   6 | loss_asc=0.0930  loss_desc=0.2585 | mean_F1=0.9328  worst_F1=0.8929
#        photo          : F1=0.9470  Acc=0.9551
#        art_painting   : F1=0.8929  Acc=0.8902
#        cartoon        : F1=0.9585  Acc=0.9531
# Epoch   7 | loss_asc=0.0744  loss_desc=0.2375 | mean_F1=0.9468  worst_F1=0.9066
#        photo          : F1=0.9853  Acc=0.9880
#        art_painting   : F1=0.9066  Acc=0.9122
#        cartoon        : F1=0.9484  Acc=0.9446
#   -> Checkpoint saved (F1=0.9468)
# Epoch   8 | loss_asc=0.0672  loss_desc=0.2152 | mean_F1=0.9421  worst_F1=0.9135
#        photo          : F1=0.9549  Acc=0.9611
#        art_painting   : F1=0.9135  Acc=0.9195
#        cartoon        : F1=0.9581  Acc=0.9531
# Epoch   9 | loss_asc=0.0535  loss_desc=0.1940 | mean_F1=0.9343  worst_F1=0.9010
#        photo          : F1=0.9590  Acc=0.9641
#        art_painting   : F1=0.9010  Acc=0.8976
#        cartoon        : F1=0.9430  Acc=0.9403
# Epoch  10 | loss_asc=0.0383  loss_desc=0.1606 | mean_F1=0.9393  worst_F1=0.9040
#        photo          : F1=0.9614  Acc=0.9671
#        art_painting   : F1=0.9040  Acc=0.9098
#        cartoon        : F1=0.9527  Acc=0.9467
# Epoch  11 | loss_asc=0.0381  loss_desc=0.1624 | mean_F1=0.9511  worst_F1=0.9256
#        photo          : F1=0.9708  Acc=0.9760
#        art_painting   : F1=0.9256  Acc=0.9220
#        cartoon        : F1=0.9569  Acc=0.9510
#   -> Checkpoint saved (F1=0.9511)
# Epoch  12 | loss_asc=0.0281  loss_desc=0.1406 | mean_F1=0.9481  worst_F1=0.9114
#        photo          : F1=0.9719  Acc=0.9760
#        art_painting   : F1=0.9114  Acc=0.9098
#        cartoon        : F1=0.9611  Acc=0.9552
# Epoch  13 | loss_asc=0.0229  loss_desc=0.1298 | mean_F1=0.9533  worst_F1=0.9311
#        photo          : F1=0.9614  Acc=0.9671
#        art_painting   : F1=0.9311  Acc=0.9317
#        cartoon        : F1=0.9675  Acc=0.9638
#   -> Checkpoint saved (F1=0.9533)
# Epoch  14 | loss_asc=0.0213  loss_desc=0.1315 | mean_F1=0.9225  worst_F1=0.8712
#        photo          : F1=0.9539  Acc=0.9611
#        art_painting   : F1=0.8712  Acc=0.8756
#        cartoon        : F1=0.9425  Acc=0.9382
# Epoch  15 | loss_asc=0.0197  loss_desc=0.1196 | mean_F1=0.9479  worst_F1=0.9166
#        photo          : F1=0.9613  Acc=0.9671
#        art_painting   : F1=0.9166  Acc=0.9171
#        cartoon        : F1=0.9659  Acc=0.9616
# Epoch  16 | loss_asc=0.0139  loss_desc=0.1087 | mean_F1=0.9504  worst_F1=0.9255
#        photo          : F1=0.9598  Acc=0.9641
#        art_painting   : F1=0.9255  Acc=0.9268
#        cartoon        : F1=0.9657  Acc=0.9616
# Epoch  17 | loss_asc=0.0159  loss_desc=0.1050 | mean_F1=0.9487  worst_F1=0.9365
#        photo          : F1=0.9582  Acc=0.9641
#        art_painting   : F1=0.9365  Acc=0.9366
#        cartoon        : F1=0.9514  Acc=0.9446
# Epoch  18 | loss_asc=0.0092  loss_desc=0.0804 | mean_F1=0.9460  worst_F1=0.9040
#        photo          : F1=0.9672  Acc=0.9731
#        art_painting   : F1=0.9040  Acc=0.9000
#        cartoon        : F1=0.9667  Acc=0.9616
# Early stopping at epoch 18
# SAM history saved.

# %%
# !python -m task3.evaluate_sketch
# Out:
# ============================================================
#   ERM
# ============================================================
#   Source validation:
#     photo          : Acc=0.9701  F1=0.9642
#     art_painting   : Acc=0.9073  F1=0.9064
#     cartoon        : Acc=0.9510  F1=0.9542
#     MEAN           : Acc=0.9428  F1=0.9416
#     WORST          : Acc=0.9073  F1=0.9064
#   Sketch: Acc=0.6951  Macro-F1=0.6658
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#   Source-domain separability (3-way LR acc): 0.8929  (chance=0.333)
#   Sharpness proxy: L(θ)=0.2018  L(θ+ε)=0.4572  Δ=0.2554
#
# ============================================================
#   DAN_DG
# ============================================================
#   Source validation:
#     photo          : Acc=0.2575  F1=0.0585
#     art_painting   : Acc=0.2195  F1=0.0514
#     cartoon        : Acc=0.1727  F1=0.0421
#     MEAN           : Acc=0.2166  F1=0.0507
#     WORST          : Acc=0.1727  F1=0.0421
#   Sketch: Acc=0.0407  Macro-F1=0.0112
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#   Source-domain separability (3-way LR acc): 0.5467  (chance=0.333)
#   Sharpness proxy: L(θ)=1.9463  L(θ+ε)=2.0161  Δ=0.0698
#
# ============================================================
#   SAM
# ============================================================
#   Source validation:
#     photo          : Acc=0.9671  F1=0.9614
#     art_painting   : Acc=0.9317  F1=0.9311
#     cartoon        : Acc=0.9638  F1=0.9675
#     MEAN           : Acc=0.9542  F1=0.9533
#     WORST          : Acc=0.9317  F1=0.9311
#   Sketch: Acc=0.7175  Macro-F1=0.7324
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#   Source-domain separability (3-way LR acc): 0.8736  (chance=0.333)
#   Sharpness proxy: L(θ)=0.1447  L(θ+ε)=0.2559  Δ=0.1112
#
# ====================================================================================================
# TASK 3 SUMMARY TABLE
# ====================================================================================================
# Method     |  Photo |  ArtPt | Cartoon | MeanSrc | WorstSrc | SketchAcc | SketchF1 |       Δ |  DomSep |   Sharp
# ----------------------------------------------------------------------------------------------------
# erm        | 0.9701 | 0.9073 |  0.9510 |  0.9428 |   0.9073 |    0.6951 |   0.6658 | +0.0000 |  0.8929 |  0.2554
# dan_dg     | 0.2575 | 0.2195 |  0.1727 |  0.2166 |   0.1727 |    0.0407 |   0.0112 | -0.6544 |  0.5467 |  0.0698
# sam        | 0.9671 | 0.9317 |  0.9638 |  0.9542 |   0.9317 |    0.7175 |   0.7324 | +0.0224 |  0.8736 |  0.1112
#
# ======================================================================
# PER-CLASS SKETCH ACCURACY
# Class        |      ERM |   dan_dg |       Δ |      sam |       Δ
# ----------------------------------------------------------------------
# dog          |   0.3199 |   0.0000 | -0.3199 |   0.3938 | +0.0738
# elephant     |   0.7716 |   0.0000 | -0.7716 |   0.8608 | +0.0892
# giraffe      |   0.6786 |   0.0000 | -0.6786 |   0.7782 | +0.0996
# guitar       |   0.8405 |   0.0000 | -0.8405 |   0.9095 | +0.0691
# horse        |   0.8664 |   0.0000 | -0.8664 |   0.6912 | -0.1752
# house        |   0.4875 |   0.0000 | -0.4875 |   0.7875 | +0.3000
# person       |   0.9062 |   1.0000 | +0.0938 |   0.7000 | -0.2063
#
# ==================================================
# SHARPNESS PROXY (rho=0.05, 32 examples/domain)
# Method     | L(θ)     | L(θ+ε)  | Δ_sharp
# --------------------------------------------------
# erm        |   0.2018 |   0.4572 |   0.2554
# dan_dg     |   1.9463 |   2.0161 |   0.0698
# sam        |   0.1447 |   0.2559 |   0.1112
# Training curves saved → task3/results/training_curves_task3.png
# Per-class delta plot saved → task3/results/per_class_sketch_delta.png
#
# All metrics saved → task3/results/final_eval_task3.json

# %%
# !python -m task3.controlled_study
# Out:
# === Expectations ===
# lambda=0.1 : weak alignment → source perf stable, dom_sep high (~ERM), sketch similar to ERM or slightly better
# lambda=1.0 : main comparison setting → moderate alignment, some drop in dom_sep, moderate effect on sketch
# lambda=10  : heavy alignment → dom_sep noticeably lower, risk of removing class-discriminative info, source perf may drop, sketch may degrade (cf. Task 2 DAN at lambda=10 which collapsed)
#
#
# --- DAN-DG  lambda_dg=0.1 ---
#   Epoch   1 | mean_src_F1=0.8387  worst=0.7757
#   Epoch   2 | mean_src_F1=0.9044  worst=0.8561
#   Epoch   3 | mean_src_F1=0.8787  worst=0.8205
#   Epoch   4 | mean_src_F1=0.9225  worst=0.8861
#   Epoch   5 | mean_src_F1=0.9149  worst=0.8660
#   Epoch   6 | mean_src_F1=0.9140  worst=0.8709
#   Epoch   7 | mean_src_F1=0.9259  worst=0.8720
#   Epoch   8 | mean_src_F1=0.9167  worst=0.8729
#   Epoch   9 | mean_src_F1=0.9399  worst=0.9257
#   Epoch  10 | mean_src_F1=0.9263  worst=0.9017
#   Epoch  11 | mean_src_F1=0.9204  worst=0.8766
#   Epoch  12 | mean_src_F1=0.9219  worst=0.8719
#   Epoch  13 | mean_src_F1=0.9332  worst=0.8763
#   Epoch  14 | mean_src_F1=0.9313  worst=0.8946
#   Early stopping at epoch 14
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#
# --- DAN-DG  lambda_dg=1.0 ---
#   Epoch   1 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   2 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   3 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   4 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   5 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   6 | mean_src_F1=0.0507  worst=0.0421
#   Early stopping at epoch 6
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#
# --- DAN-DG  lambda_dg=10.0 ---
#   Epoch   1 | mean_src_F1=0.0364  worst=0.0312
#   Epoch   2 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   3 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   4 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   5 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   6 | mean_src_F1=0.0507  worst=0.0421
#   Epoch   7 | mean_src_F1=0.0507  worst=0.0421
#   Early stopping at epoch 7
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
#
#   lambda |   SrcAcc |   SrcF1 |  WrstF1 | SketchAcc | SketchF1 |  DomSep |   Sharp
# --------------------------------------------------------------------------------
#      0.1 |   0.9403 |  0.9399 |  0.9257 |    0.6895 |   0.6811 |  0.8407 |  0.1683
#      1.0 |   0.2166 |  0.0507 |  0.0421 |    0.0407 |   0.0112 |  0.6374 |  0.0740
#     10.0 |   0.2166 |  0.0507 |  0.0421 |    0.0407 |   0.0112 |  0.5495 |  0.0411
#
# Plot saved → task3/results/controlled_study_dan_dg.png
# Results saved → task3/results/controlled_study_dan_dg.json
